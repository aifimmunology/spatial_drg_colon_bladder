# %%
from datetime import datetime

print(f"Timestamp: {datetime.now()}")
# Out:
# Timestamp: 2025-11-25 10:48:56.997441

# %% [markdown]
# # Doublet scoring

# %% [markdown]
# Run scrublet after light filtering, on individual samples prior to concatenation.

# %%
import os
from pathlib import Path
import scanpy as sc
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scrublet as scr
import sys
import anndata as ad
import session_info

# %%
plt.rcParams['figure.figsize'] = (3,3)

# %%
base_dir = Path('/home/workspace/projects/drg')
input_dirs = {
    "whole": base_dir / "data/h5ad/export_01/03a_pre-filtered/whole",
    "nuclear": base_dir / "data/h5ad/export_01/03b_pre-filtered/nuclear_only",
}
output_dirs = {
    "whole": base_dir / "data/h5ad/export_01/04a_scrublet/whole",
    "nuclear": base_dir / "data/h5ad/export_01/04b_scrublet/nuclear_only",
}
scrublet_dir = base_dir / "scrublet"
scrublet_dir.mkdir(exist_ok=True)

for d in output_dirs.values():
    d.mkdir(parents=True, exist_ok=True)

# %%
whole_files = sorted(
    f for f in os.listdir(input_dirs["whole"])
    if f.endswith(".h5ad") and f.startswith("TMA")
)
nuclear_files = sorted(
    f for f in os.listdir(input_dirs["nuclear"])
    if f.endswith(".h5ad") and f.startswith("TMA")
)

whole_adata_list = [
    ad.read_h5ad(input_dirs["whole"] / f).copy()
    for f in whole_files
]
nuclear_adata_list = [
    ad.read_h5ad(input_dirs["nuclear"] / f).copy()
    for f in nuclear_files
]

# %%
def run_scrublet(adata_list, scrublet_dir):
    for i, adata in enumerate(adata_list):
        sample_id = adata.obs["output_id"].iloc[0]
        print(f"\nRunning Scrublet for {sample_id}...")

        scrub = scr.Scrublet(adata.X, expected_doublet_rate=0.05)
        doublet_scores, predicted_doublets = scrub.scrub_doublets(
            min_counts=2, 
            min_cells=3, 
            min_gene_variability_pctl=85, 
            n_prin_comps=30
        )

        # Determine threshold
        threshold = scrub.threshold_ if scrub.threshold_ else scrub.doublet_scores_sim_.mean() + 2 * scrub.doublet_scores_sim_.std()
        if scrub.threshold_:
            print(f"Scrublet auto-set threshold for {sample_id}: {threshold:.3f}")
        else:
            print(f"Using fallback threshold for {sample_id}: {threshold:.3f}")

        predicted_doublets = scrub.call_doublets(threshold=threshold)

        # Annotate results
        adata.obs["doublet_scores"] = doublet_scores
        adata.obs["predicted_doublets"] = predicted_doublets

        # Save histogram
        plt.figure(figsize=(10, 6))
        sns.histplot(scrub.doublet_scores_obs_, bins=30, color="blue", label="Observed", kde=True)
        sns.histplot(scrub.doublet_scores_sim_, bins=30, color="red", label="Simulated", kde=True)
        plt.axvline(threshold, color='green', linestyle='--', label=f'Threshold: {threshold:.3f}')
        plt.title(f'Scrublet Doublet Score Distribution for {sample_id}')
        plt.xlabel("Doublet Score")
        plt.ylabel("Density")
        plt.legend()
        plt.tight_layout()
        plt.show()

        # Save Scrublet scores
        scrublet_df = pd.DataFrame({
            "Sample_ID": sample_id,
            "Cell_Barcode": adata.obs_names,
            "Doublet_Score": doublet_scores,
            "Predicted_Doublet": predicted_doublets,
        })
        csv_path = scrublet_dir / f"{sample_id}_scrublet_results.csv"
        scrublet_df.to_csv(csv_path, index=False)
        print(f"Saved Scrublet CSV for {sample_id} to {csv_path}")

# %%
print("\n Running Scrublet on whole-cell runs")
run_scrublet(whole_adata_list, scrublet_dir)

print("\n Running Scrublet on nuclear-only runs")
run_scrublet(nuclear_adata_list, scrublet_dir)
# Out:
#  Running Scrublet on whole-cell runs
#
# Running Scrublet for TMA00307...
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# /home/workspace/environment/sc-scrublet/lib/python3.12/site-packages/scrublet/helper_functions.py:252: RuntimeWarning: invalid value encountered in sqrt
#   CV_input = np.sqrt(b);
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.21
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.0%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 100.0%
# Elapsed time: 3.1 seconds
# Scrublet auto-set threshold for TMA00307: 0.211
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.0%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 100.0%
# Saved Scrublet CSV for TMA00307 to /home/workspace/projects/drg/scrublet/TMA00307_scrublet_results.csv
#
# Running Scrublet for TMA00308...
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# /home/workspace/environment/sc-scrublet/lib/python3.12/site-packages/scrublet/helper_functions.py:252: RuntimeWarning: invalid value encountered in sqrt
#   CV_input = np.sqrt(b);
# Automatically set threshold at doublet score = 0.20
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.0%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.0%
# Elapsed time: 2.8 seconds
# Scrublet auto-set threshold for TMA00308: 0.197
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.0%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.0%
# Saved Scrublet CSV for TMA00308 to /home/workspace/projects/drg/scrublet/TMA00308_scrublet_results.csv
#
# Running Scrublet for TMA00311...
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.30
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.0%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.0%
# Elapsed time: 13.7 seconds
# Scrublet auto-set threshold for TMA00311: 0.296
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.0%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.0%
# Saved Scrublet CSV for TMA00311 to /home/workspace/projects/drg/scrublet/TMA00311_scrublet_results.csv
#
#  Running Scrublet on nuclear-only runs
#
# Running Scrublet for TMA00307...
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# /home/workspace/environment/sc-scrublet/lib/python3.12/site-packages/scrublet/helper_functions.py:321: RuntimeWarning: divide by zero encountered in divide
#   w.setdiag(float(target_total) / tots_use)
# /home/workspace/environment/sc-scrublet/lib/python3.12/site-packages/scrublet/helper_functions.py:252: RuntimeWarning: invalid value encountered in sqrt
#   CV_input = np.sqrt(b);
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.33
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.1%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.0%
# Elapsed time: 2.8 seconds
# Scrublet auto-set threshold for TMA00307: 0.329
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.1%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.0%
# Saved Scrublet CSV for TMA00307 to /home/workspace/projects/drg/scrublet/TMA00307_scrublet_results.csv
#
# Running Scrublet for TMA00308...
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# /home/workspace/environment/sc-scrublet/lib/python3.12/site-packages/scrublet/helper_functions.py:321: RuntimeWarning: divide by zero encountered in divide
#   w.setdiag(float(target_total) / tots_use)
# /home/workspace/environment/sc-scrublet/lib/python3.12/site-packages/scrublet/helper_functions.py:252: RuntimeWarning: invalid value encountered in sqrt
#   CV_input = np.sqrt(b);
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.25
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.0%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.0%
# Elapsed time: 2.8 seconds
# Scrublet auto-set threshold for TMA00308: 0.252
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.0%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.0%
# Saved Scrublet CSV for TMA00308 to /home/workspace/projects/drg/scrublet/TMA00308_scrublet_results.csv
#
# Running Scrublet for TMA00311...
# Preprocessing...
# Simulating doublets...
# /home/workspace/environment/sc-scrublet/lib/python3.12/site-packages/scrublet/helper_functions.py:321: RuntimeWarning: divide by zero encountered in divide
#   w.setdiag(float(target_total) / tots_use)
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.26
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.0%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 28.6%
# Elapsed time: 13.6 seconds
# Scrublet auto-set threshold for TMA00311: 0.261
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.0%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 28.6%
# Saved Scrublet CSV for TMA00311 to /home/workspace/projects/drg/scrublet/TMA00311_scrublet_results.csv

# %% [markdown]
# ## Export

# %%
def export_anndata(adata_list, out_dir):
    out_dir = Path(out_dir)  
    for adata in adata_list:
        sample_id = adata.obs["output_id"].iloc[0]
        output_path = out_dir / f"{sample_id}.h5ad"
        adata.write(output_path)
        print(f"Saved filtered AnnData for {sample_id} to {output_path}")


export_anndata(whole_adata_list, output_dirs["whole"])
export_anndata(nuclear_adata_list, output_dirs["nuclear"])
# Out:
# Saved filtered AnnData for TMA00307 to /home/workspace/projects/drg/data/h5ad/export_01/04a_scrublet/whole/TMA00307.h5ad
# Saved filtered AnnData for TMA00308 to /home/workspace/projects/drg/data/h5ad/export_01/04a_scrublet/whole/TMA00308.h5ad
# Saved filtered AnnData for TMA00311 to /home/workspace/projects/drg/data/h5ad/export_01/04a_scrublet/whole/TMA00311.h5ad
# Saved filtered AnnData for TMA00307 to /home/workspace/projects/drg/data/h5ad/export_01/04b_scrublet/nuclear_only/TMA00307.h5ad
# Saved filtered AnnData for TMA00308 to /home/workspace/projects/drg/data/h5ad/export_01/04b_scrublet/nuclear_only/TMA00308.h5ad
# Saved filtered AnnData for TMA00311 to /home/workspace/projects/drg/data/h5ad/export_01/04b_scrublet/nuclear_only/TMA00311.h5ad

# %% [markdown]
# ## Session info

# %%
print('active IDE: sc-sq')
print('active conda environment:', os.path.basename(sys.prefix))
session_info.show()
# Out:
# active IDE: sc-sq
# active conda environment: sc-scrublet
# <details>
# <summary>Click to view session information</summary>
# <pre>
# -----
# anndata             0.11.3
# matplotlib          3.10.0
# pandas              2.2.3
# scanpy              1.10.4
# scrublet            NA
# seaborn             0.13.2
# session_info        1.0.0
# -----
# </pre>
# <details>
# <summary>Click to view modules imported as dependencies</summary>
# <pre>
# Cython              3.0.12
# PIL                 11.1.0
# annoy               NA
# asttokens           NA
# colorama            0.4.6
# comm                0.2.2
# cycler              0.12.1
# cython              3.0.12
# cython_runtime      NA
# dateutil            2.9.0.post0
# debugpy             1.8.12
# decorator           5.1.1
# executing           2.1.0
# h5py                3.12.1
# igraph              0.11.8
# ipykernel           6.29.5
# jedi                0.19.2
# joblib              1.4.2
# kiwisolver          1.4.8
# lazy_loader         0.4
# legacy_api_wrap     NA
# leidenalg           0.10.2
# llvmlite            0.44.0
# matplotlib_inline   0.1.7
# mpl_toolkits        NA
# natsort             8.4.0
# numba               0.61.0
# numpy               1.26.4
# packaging           24.1
# parso               0.8.4
# patsy               1.0.1
# pickleshare         0.7.5
# platformdirs        4.3.6
# plotly              5.23.0
# prompt_toolkit      3.0.50
# psutil              6.1.1
# pure_eval           0.2.3
# pydev_ipython       NA
# pydevconsole        NA
# pydevd              3.2.3
# pydevd_file_utils   NA
# pydevd_plugins      NA
# pydevd_tracing      NA
# pygments            2.19.1
# pyparsing           3.2.1
# pytz                2024.2
# scipy               1.15.1
# six                 1.16.0
# skimage             0.25.2
# sklearn             1.6.1
# stack_data          0.6.3
# statsmodels         0.14.4
# texttable           1.7.0
# threadpoolctl       3.5.0
# tornado             6.4.2
# traitlets           5.14.3
# wcwidth             0.2.13
# yaml                6.0.2
# zmq                 26.2.0
# </pre>
# </details> <!-- seems like this ends pre, so might as well be explicit -->
# <pre>
# -----
# IPython             8.31.0
# jupyter_client      8.6.3
# jupyter_core        5.7.2
# -----
# Python 3.12.8 | packaged by conda-forge | (main, Dec  5 2024, 14:24:40) [GCC 13.3.0]
# Linux-6.6.87+-x86_64-with-glibc2.35
# -----
# Session information updated at 2025-11-25 10:49
# </pre>
# </details>
