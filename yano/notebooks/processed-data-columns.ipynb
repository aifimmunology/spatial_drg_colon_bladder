# %% [markdown]
# # GEO Processed data final

# %%
import os
from pathlib import Path
import scanpy as sc
import numpy as np
from scipy.sparse import issparse, csr_matrix
import pandas as pd
import numpy as np
import anndata as ad
import matplotlib.pyplot as plt
import warnings
import session_info
import sys

# %%
data_dir = Path("/home/workspace/temp/geo_organized")

adata_path = os.path.join(data_dir, 'adata_processed.h5ad')

# %%
adata = sc.read_h5ad(adata_path)

# %%
adata.obs.columns
# Out:
# Index(['cell_id', 'x_centroid', 'y_centroid', 'total_counts', 'cell_area',
#        'nucleus_area', 'nucleus_count', 'segmentation_method', 'sample_id',
#        'slide_id', 'n_genes_by_counts', 'cell_type', 'cell_class',
#        'EGFP_Seq1_hi', 'dTomato_Seq2_hi', 'EGFP_dTomato_dual_hi',
#        'reporter_status', 'innervation_pattern', 'neuron_filter'],
#       dtype='object')

# %%
adata.obs.cell_type.value_counts()
# Out:
# cell_type
# Schwann_cell                  26709
# SGC                           17770
# Fibroblast_1                  10454
# Vascular_endothelial_1         8456
# Macrophage_1                   7258
# CGRP-Gamma 1                   4103
# Fibroblast_2                   4002
# Nonpeptidergic nociceptors     3513
# Mixed                          3359
# Pericyte                       2800
# CGRP-Gamma 2                   2083
# CGRP-Eta                       1963
# CGRP-Zeta                      1493
# Abeta-RA-LTMR                  1463
# Abeta-Field                    1452
# C-LTMR                         1402
# Vascular_endothelial_2         1381
# Adelta-LTMR                    1020
# CGRP-Theta                      868
# Proprioceptors                  864
# nan                             786
# TrpM8                           650
# CGRP-Epsilion                   609
# Sst                             554
# Angiogenic EC                   280
# CGRP-Alpha                      245
# CGRP-Beta                       129
# Unknown                          99
# Cycling SGC                      91
# Name: count, dtype: int64
