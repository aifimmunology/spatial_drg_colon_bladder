# %% [markdown]
# # Download samples from HISE

# %% [markdown]
# This script uses the HISE `cache_files()` function to download a list of Xenium runs into specified directories.

# %%
import os
import hisepy as hp
import shutil 
import zipfile 
import sys

# %%
data_dir = '/home/workspace/data/temp/DRG'
os.makedirs(data_dir, exist_ok=True)

# %% [markdown]
# ## Normal download

# %%
file_ids = [
    "db4cac69-6113-4ff0-b893-6b22700aefd6", #TMA00315
    "a96820d7-2442-48c1-ab78-44c282013118", #TMA00316
    "98eb3fa7-562f-4c7c-a8eb-616f5c3efa64", #TMA00317
    "75d0c30b-95b3-47fa-a3fa-037426c49f95", #TMA00318
]

# %%
def cache_and_unzip_from_HISE(file_ids, data_input_folder):
    
    # cache files to input folder
    filepaths = hp.cache_files(file_ids)

    # move files to data_input_folder
    for file in filepaths:
        if os.path.exists(file):  
            shutil.copy2(file, data_input_folder)
            print(f"Copied: {file} -> {data_input_folder}")

            # Unzip the file
            file_name = os.path.basename(file)  # Extract filename from path
            zip_path = os.path.join(data_input_folder, file_name)  # Full path to copied file
            
            if zipfile.is_zipfile(zip_path):  # Check if it's a valid zip file
                with zipfile.ZipFile(zip_path, 'r') as zip_ref:
                    extract_path = data_input_folder
                    zip_ref.extractall(extract_path)
                    print(f"Unzipped: {zip_path} -> {extract_path}")

                # Delete the .zip file after extraction
                os.remove(zip_path)
                print(f"Deleted: {zip_path}")
            else:
                print(f"Not a valid zip file: {zip_path}")

        else:
            print(f"File not found: {file}")

# %%
cache_and_unzip_from_HISE(file_ids, data_dir)
# Out:
# Copied: /home/workspace/input/3780025679/TINI_Mouse/db4cac69-6113-4ff0-b893-6b22700aefd6/AIFI-2025-12-24T01:42:12.259543021Z/output-XETG00123__0076900__TMA00315__20251219__223811.zip -> /home/workspace/data/temp/DRG
# Unzipped: /home/workspace/data/temp/DRG/output-XETG00123__0076900__TMA00315__20251219__223811.zip -> /home/workspace/data/temp/DRG
# Deleted: /home/workspace/data/temp/DRG/output-XETG00123__0076900__TMA00315__20251219__223811.zip
# Copied: /home/workspace/input/3780025679/TINI_Mouse/a96820d7-2442-48c1-ab78-44c282013118/AIFI-2025-12-24T01:43:05.471709097Z/output-XETG00123__0076900__TMA00316__20251219__223811.zip -> /home/workspace/data/temp/DRG
# Unzipped: /home/workspace/data/temp/DRG/output-XETG00123__0076900__TMA00316__20251219__223811.zip -> /home/workspace/data/temp/DRG
# Deleted: /home/workspace/data/temp/DRG/output-XETG00123__0076900__TMA00316__20251219__223811.zip
# Copied: /home/workspace/input/3780025679/TINI_Mouse/98eb3fa7-562f-4c7c-a8eb-616f5c3efa64/AIFI-2025-12-24T01:43:52.450352823Z/output-XETG00123__0076901__TMA00317__20251219__223811.zip -> /home/workspace/data/temp/DRG
# Unzipped: /home/workspace/data/temp/DRG/output-XETG00123__0076901__TMA00317__20251219__223811.zip -> /home/workspace/data/temp/DRG
# Deleted: /home/workspace/data/temp/DRG/output-XETG00123__0076901__TMA00317__20251219__223811.zip
# Copied: /home/workspace/input/3780025679/TINI_Mouse/75d0c30b-95b3-47fa-a3fa-037426c49f95/AIFI-2025-12-24T01:45:23.434184629Z/output-XETG00123__0076901__TMA00318__20251219__223811.zip -> /home/workspace/data/temp/DRG
# Unzipped: /home/workspace/data/temp/DRG/output-XETG00123__0076901__TMA00318__20251219__223811.zip -> /home/workspace/data/temp/DRG
# Deleted: /home/workspace/data/temp/DRG/output-XETG00123__0076901__TMA00318__20251219__223811.zip
