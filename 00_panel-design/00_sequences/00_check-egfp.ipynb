# %% [markdown]
# ## See if EGFP in the mice and in the AAV are the same sequence

# %%
import difflib

# %% [markdown]
# Mouse: https://www.addgene.org/181760/
#
# * EGFP BP: 7291 .. 8007
#
#
# Virus: https://www.addgene.org/browse/sequence/240907/
#
# * EGFP BP: 653 .. 1372

# %%
# From online entries
ai224_sequence = "..."
aav_sequence = "..."

# %%
print("Length of full mouse (AI224) sequence:", len(ai224_sequence))
print("Length of full virus (AAV) sequence:", len(aav_sequence))
# Out:
# Length of full mouse (AI224) sequence: 17036
# Length of full virus (AAV) sequence: 5265

# %% [markdown]
# There is partial overlap in the EGFP sequences.

# %%
# EGFP coordinates are 1-based inclusive, convert to 0-based Python indexing
mouse_start, mouse_end = 7290, 8007  # Mouse EGFP from Addgene (717 bp)
virus_start, virus_end = 652, 1372   # Virus EGFP from Addgene (720 bp)

# Extract the sequences
mouse_egfp_seq = ai224_sequence[mouse_start:mouse_end]  # 717 bp
virus_egfp_seq = aav_sequence[virus_start:virus_end]    # 720 bp

# Print the sequences
print("Mouse EGFP sequence:\n", mouse_egfp_seq)
print("\nVirus EGFP sequence:\n", virus_egfp_seq)

# Optional: check if one is in the other
print("\nMouse EGFP in Virus EGFP:", mouse_egfp_seq in virus_egfp_seq)
# Out:
# Mouse EGFP sequence:
#  ...
#
# Virus EGFP sequence:
#  ...
#
# Mouse EGFP in Virus EGFP: False

# %% [markdown]
# ### Look for the eGFP sequence in both

# %%
egfp_sequence = "..."

# %%
def find_sequence_in_target(target_seq, query_seq, target_name):
    pos = target_seq.find(query_seq)
    if pos != -1:
        print(f"Exact match found in {target_name} at position {pos} (0-based index)")
        print(f"Match spans positions {pos} to {pos + len(query_seq) - 1}")
    else:
        print(f"No exact match found in {target_name}")

find_sequence_in_target(ai224_sequence, egfp_sequence, "ai224_sequence")
find_sequence_in_target(aav_sequence, egfp_sequence, "aav_sequence")
# Out:
# Exact match found in ai224_sequence at position 7290 (0-based index)
# Match spans positions 7290 to 7990
# Exact match found in aav_sequence at position 655 (0-based index)
# Match spans positions 655 to 1355

# %%
len(egfp_sequence)
# Out:
# 701
