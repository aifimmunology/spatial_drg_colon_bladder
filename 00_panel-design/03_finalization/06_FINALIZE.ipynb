# %% [markdown]
# # Panel design draft

# %% [markdown]
# Start from the draft shared on 7/10/25

# %%
from pathlib import Path
import sys
import scanpy as sc
import scipy
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import session_info
import warnings
warnings.filterwarnings('ignore')

# %%
plt.rcParams['figure.figsize'] = (4,4)

# %% [markdown]
# ## Import the reference datasets

# %%
base_dir = Path('/home/workspace/private/projects/kim/drg')
panel_dir = base_dir / 'panel/gene-lists'

input_dir = panel_dir / 'output' # this is where the persist output is
output_dir = panel_dir / 'output'

Path(output_dir).mkdir(parents=True, exist_ok=True)

# %%
adata_path = base_dir / 'data/scrna-seq/h5ad/04_clustered/GSE139088-scvi-leiden.h5ad'
bdata_path = base_dir / 'data/scrna-seq/h5ad/04_clustered/GSE254789-nonneurons.h5ad'

draft_path = panel_dir / 'drafts/2025-07-09_panel-draft_473g.csv'

# %%
adata = sc.read_h5ad(adata_path)
bdata = sc.read_h5ad(bdata_path)

# %%
adata_list = [adata, bdata]

# %%
panel = pd.read_csv(draft_path)
panel_full = panel.copy()  # preserve full for Notes access

# Subset to first 10 columns
panel = panel.iloc[:, :10]

# Add 'Notes' column if it exists in the original
if "Notes" in panel_full.columns:
    panel["Notes"] = panel_full["Notes"]

panel
# Out:
#          Gene          Ensembl ID  Probesets  zhen_list  spectral_panel  \
# 0       Pdcd1  ENSMUSG00000026285          8       True            True
# 1      Adra2a  ENSMUSG00000033717          8       True           False
# 2       Il1r1  ENSMUSG00000026072          8       True           False
# 3       Il6st  ENSMUSG00000021756          8       True           False
# 4    Tnfrsf1a  ENSMUSG00000030341          8       True           False
# ..        ...                 ...        ...        ...             ...
# 468     Ctxn3  ENSMUSG00000069372          8      False           False
# 469     Pvalb  ENSMUSG00000005716          8      False           False
# 470    Clec2l  ENSMUSG00000079598          8      False           False
# 471    Snhg11  ENSMUSG00000044349          8      False           False
# 472     Fabp7  ENSMUSG00000019874          4      False           False
#
#      neurons_supervised  neurons_unsupervised  glia_supervised  \
# 0                 False                 False            False
# 1                 False                 False            False
# 2                 False                 False            False
# 3                 False                 False            False
# 4                 False                 False            False
# ..                  ...                   ...              ...
# 468               False                 False            False
# 469               False                 False            False
# 470               False                 False            False
# 471               False                 False            False
# 472               False                 False            False
#
#      glia_unsupervised  other                     Notes
# 0                False  False                       NaN
# 1                False  False                       NaN
# 2                False  False                       NaN
# 3                False  False                       NaN
# 4                False  False                       NaN
# ..                 ...    ...                       ...
# 468              False   True  Neuronal DEGs (Wilcoxon)
# 469              False   True  Neuronal DEGs (Wilcoxon)
# 470              False   True  Neuronal DEGs (Wilcoxon)
# 471              False   True  Neuronal DEGs (Wilcoxon)
# 472              False   True      Classical SGC marker
#
# [473 rows x 11 columns]

# %% [markdown]
# ## Populate columns for new genes

# %%
boolean_columns = [
    "zhen_list",
    "spectral_panel",
    "neurons_supervised",
    "neurons_unsupervised",
    "glia_supervised",
    "glia_unsupervised",
    "other"
]

# %%
# 1. Set 'neuron_DEGs' to True based on Notes
panel["neuron_DEGs"] = False
mask = panel["Notes"] == "Neuronal DEGs (Wilcoxon)"
panel.loc[mask, "neuron_DEGs"] = True
panel.loc[mask, [col for col in boolean_columns if col != "neuron_DEGs"]] = False

# 2. For Fabp7, set 'other' to True, rest of booleans to False
fabp7_mask = panel["Gene"] == "Fabp7"
for col in boolean_columns:
    panel.loc[fabp7_mask, col] = (col == "other")

# 3. Reorder columns to place 'neuron_DEGs' after 'other'
cols = list(panel.columns)
if "neuron_DEGs" in cols:
    cols.remove("neuron_DEGs")
    insert_at = cols.index("other") + 1
    cols.insert(insert_at, "neuron_DEGs")
    panel = panel[cols]

# %%
panel
# Out:
#          Gene          Ensembl ID  Probesets  zhen_list  spectral_panel  \
# 0       Pdcd1  ENSMUSG00000026285          8       True            True
# 1      Adra2a  ENSMUSG00000033717          8       True           False
# 2       Il1r1  ENSMUSG00000026072          8       True           False
# 3       Il6st  ENSMUSG00000021756          8       True           False
# 4    Tnfrsf1a  ENSMUSG00000030341          8       True           False
# ..        ...                 ...        ...        ...             ...
# 468     Ctxn3  ENSMUSG00000069372          8      False           False
# 469     Pvalb  ENSMUSG00000005716          8      False           False
# 470    Clec2l  ENSMUSG00000079598          8      False           False
# 471    Snhg11  ENSMUSG00000044349          8      False           False
# 472     Fabp7  ENSMUSG00000019874          4      False           False
#
#      neurons_supervised  neurons_unsupervised  glia_supervised  \
# 0                 False                 False            False
# 1                 False                 False            False
# 2                 False                 False            False
# 3                 False                 False            False
# 4                 False                 False            False
# ..                  ...                   ...              ...
# 468               False                 False            False
# 469               False                 False            False
# 470               False                 False            False
# 471               False                 False            False
# 472               False                 False            False
#
#      glia_unsupervised  other  neuron_DEGs                     Notes
# 0                False  False        False                       NaN
# 1                False  False        False                       NaN
# 2                False  False        False                       NaN
# 3                False  False        False                       NaN
# 4                False  False        False                       NaN
# ..                 ...    ...          ...                       ...
# 468              False  False         True  Neuronal DEGs (Wilcoxon)
# 469              False  False         True  Neuronal DEGs (Wilcoxon)
# 470              False  False         True  Neuronal DEGs (Wilcoxon)
# 471              False  False         True  Neuronal DEGs (Wilcoxon)
# 472              False   True        False      Classical SGC marker
#
# [473 rows x 12 columns]

# %% [markdown]
# # Rename entries in adata.var
# For compatibility with current genome build

# %%
adata.var
# Out:
#                   mt  ribosomal  n_cells_by_counts  mean_counts  \
# 0610007P14Rik  False      False               6287     1.125146
# 0610009B22Rik  False      False               7134     1.895682
# 0610009L18Rik  False      False               2742     0.306491
# 0610009O20Rik  False      False               1629     0.162851
# 0610010F05Rik  False      False               8274     1.754825
# ...              ...        ...                ...          ...
# Zyg11a         False      False                  0     0.000000
# Zyg11b         False      False               8463     1.715594
# Zyx            False      False               3661     0.455606
# Zzef1          False      False               6723     1.036538
# Zzz3           False      False               4933     0.622498
#
#                pct_dropout_by_counts  total_counts
# 0610007P14Rik              43.558668       12533.0
# 0610009B22Rik              35.954754       21116.0
# 0610009L18Rik              75.383787        3414.0
# 0610009O20Rik              85.375707        1814.0
# 0610010F05Rik              25.720442       19547.0
# ...                              ...           ...
# Zyg11a                    100.000000           0.0
# Zyg11b                     24.023701       19110.0
# Zyx                        67.133495        5075.0
# Zzef1                      39.644492       11546.0
# Zzz3                       55.714157        6934.0
#
# [20924 rows x 6 columns]

# %%
# Gene name update mapping
gene_updates = {
    "Fam19a1": "Tafa1",
    "Mrgprc11": "Mrgprx1",
    "Cyr61": "Ccn1",
    "2810417H13Rik": "Pclaf",
    "Fam19a5": "Tafa5",
    "Fam19a4": "Tafa4",
    "Abcb1": "Abcb1a"
}

# Apply updates and freeze log1p layer into .raw
for ad in adata_list:
    ad.var.rename(index=gene_updates, inplace=True)
    ad.var_names = ad.var.index
    ad.X = ad.layers["log1p"]
    ad.raw = ad.copy()

# %%
# Print renamed genes found in .var_names
print([gene for gene in gene_updates.values() if gene in adata.var_names])

# Print original (unrenamed) genes still present
print([gene for gene in gene_updates.keys() if gene in adata.var_names])
# Out:
# ['Tafa1', 'Mrgprx1', 'Ccn1', 'Pclaf', 'Tafa5', 'Tafa4', 'Abcb1a']
# []

# %%
for ad in adata_list:
    sc.pl.umap(ad, color = 'Tafa4')

# %% [markdown]
# # Final modifcations

# %% [markdown]
# ## add genes

# %%
genes_to_add = [
    "Siglecf", "Cd200r3", "Itga2", "Gata3", "Thy1", "Il5", "S100a8", "S100a9", "Gfap"
]

# Step 1: Create new rows for genes not already in panel
new_genes_df = pd.DataFrame({'Gene': genes_to_add})
new_genes_df = new_genes_df[~new_genes_df['Gene'].isin(panel['Gene'])]

# Step 2: Reindex to match panel's structure
new_genes_df = new_genes_df.reindex(columns=panel.columns)

# Step 3: Set boolean columns to False for new genes
new_genes_df[boolean_columns] = False

# Step 4: Optional — set neuron_DEGs explicitly (if present)
if "neuron_DEGs" in new_genes_df.columns:
    new_genes_df["neuron_DEGs"] = False

# Step 5: Append
panel = pd.concat([panel, new_genes_df], ignore_index=True)
panel
# Out:
#          Gene          Ensembl ID  Probesets  zhen_list  spectral_panel  \
# 0       Pdcd1  ENSMUSG00000026285        8.0       True            True
# 1      Adra2a  ENSMUSG00000033717        8.0       True           False
# 2       Il1r1  ENSMUSG00000026072        8.0       True           False
# 3       Il6st  ENSMUSG00000021756        8.0       True           False
# 4    Tnfrsf1a  ENSMUSG00000030341        8.0       True           False
# ..        ...                 ...        ...        ...             ...
# 476     Gata3                 NaN        NaN      False           False
# 477       Il5                 NaN        NaN      False           False
# 478    S100a8                 NaN        NaN      False           False
# 479    S100a9                 NaN        NaN      False           False
# 480      Gfap                 NaN        NaN      False           False
#
#      neurons_supervised  neurons_unsupervised  glia_supervised  \
# 0                 False                 False            False
# 1                 False                 False            False
# 2                 False                 False            False
# 3                 False                 False            False
# 4                 False                 False            False
# ..                  ...                   ...              ...
# 476               False                 False            False
# 477               False                 False            False
# 478               False                 False            False
# 479               False                 False            False
# 480               False                 False            False
#
#      glia_unsupervised  other  neuron_DEGs Notes
# 0                False  False        False   NaN
# 1                False  False        False   NaN
# 2                False  False        False   NaN
# 3                False  False        False   NaN
# 4                False  False        False   NaN
# ..                 ...    ...          ...   ...
# 476              False  False        False   NaN
# 477              False  False        False   NaN
# 478              False  False        False   NaN
# 479              False  False        False   NaN
# 480              False  False        False   NaN
#
# [481 rows x 12 columns]

# %% [markdown]
# ## Remove genes

# %%
genes_to_remove = [
    "Tigit", "Il17a", "Prf1", "Cdc20", "mt-Nd6", "Gja5"

]

panel = panel[~panel['Gene'].isin(genes_to_remove)]
panel
# Out:
#          Gene          Ensembl ID  Probesets  zhen_list  spectral_panel  \
# 0       Pdcd1  ENSMUSG00000026285        8.0       True            True
# 1      Adra2a  ENSMUSG00000033717        8.0       True           False
# 2       Il1r1  ENSMUSG00000026072        8.0       True           False
# 3       Il6st  ENSMUSG00000021756        8.0       True           False
# 4    Tnfrsf1a  ENSMUSG00000030341        8.0       True           False
# ..        ...                 ...        ...        ...             ...
# 476     Gata3                 NaN        NaN      False           False
# 477       Il5                 NaN        NaN      False           False
# 478    S100a8                 NaN        NaN      False           False
# 479    S100a9                 NaN        NaN      False           False
# 480      Gfap                 NaN        NaN      False           False
#
#      neurons_supervised  neurons_unsupervised  glia_supervised  \
# 0                 False                 False            False
# 1                 False                 False            False
# 2                 False                 False            False
# 3                 False                 False            False
# 4                 False                 False            False
# ..                  ...                   ...              ...
# 476               False                 False            False
# 477               False                 False            False
# 478               False                 False            False
# 479               False                 False            False
# 480               False                 False            False
#
#      glia_unsupervised  other  neuron_DEGs Notes
# 0                False  False        False   NaN
# 1                False  False        False   NaN
# 2                False  False        False   NaN
# 3                False  False        False   NaN
# 4                False  False        False   NaN
# ..                 ...    ...          ...   ...
# 476              False  False        False   NaN
# 477              False  False        False   NaN
# 478              False  False        False   NaN
# 479              False  False        False   NaN
# 480              False  False        False   NaN
#
# [475 rows x 12 columns]

# %% [markdown]
# # Calculate gene detection rate

# %%
# Check how many duplicates there are
dup_counts = panel["Gene"].value_counts()
duplicates = dup_counts[dup_counts > 1]
print("Duplicate genes after renaming:\n", duplicates)
# Out:
# Duplicate genes after renaming:
#  Series([], Name: count, dtype: int64)

# %%
# Step 1: Build detection matrix across adata_list
gene_detection_matrix = pd.DataFrame(index=panel["Gene"])

for i, ad in enumerate(adata_list):
    col_name = f"adata_{i}"
    detected_genes = gene_detection_matrix.index.intersection(ad.var_names)
    detection_percent = (ad[:, detected_genes].X > 0).sum(axis=0) / ad.n_obs * 100
    gene_detection_matrix.loc[detected_genes, col_name] = (
        detection_percent.A1 if hasattr(detection_percent, "A1") else detection_percent
    )

# Step 2: Rename columns to match desired names
gene_detection_matrix = gene_detection_matrix.rename(columns={
    "adata_0": "neuron_detection_rate",
    "adata_1": "glia_detection_rate"
})

# Step 3: Calculate combined detection rate
gene_detection_matrix["combined_detection_rate"] = gene_detection_matrix[
    ["neuron_detection_rate", "glia_detection_rate"]
].mean(axis=1, skipna=True)

# Step 4: Merge into panel
panel = panel.merge(
    gene_detection_matrix,
    how="left",
    left_on="Gene",
    right_index=True
)

# %%
panel
# Out:
#          Gene          Ensembl ID  Probesets  zhen_list  spectral_panel  \
# 0       Pdcd1  ENSMUSG00000026285        8.0       True            True
# 1      Adra2a  ENSMUSG00000033717        8.0       True           False
# 2       Il1r1  ENSMUSG00000026072        8.0       True           False
# 3       Il6st  ENSMUSG00000021756        8.0       True           False
# 4    Tnfrsf1a  ENSMUSG00000030341        8.0       True           False
# ..        ...                 ...        ...        ...             ...
# 476     Gata3                 NaN        NaN      False           False
# 477       Il5                 NaN        NaN      False           False
# 478    S100a8                 NaN        NaN      False           False
# 479    S100a9                 NaN        NaN      False           False
# 480      Gfap                 NaN        NaN      False           False
#
#      neurons_supervised  neurons_unsupervised  glia_supervised  \
# 0                 False                 False            False
# 1                 False                 False            False
# 2                 False                 False            False
# 3                 False                 False            False
# 4                 False                 False            False
# ..                  ...                   ...              ...
# 476               False                 False            False
# 477               False                 False            False
# 478               False                 False            False
# 479               False                 False            False
# 480               False                 False            False
#
#      glia_unsupervised  other  neuron_DEGs Notes  neuron_detection_rate  \
# 0                False  False        False   NaN                    NaN
# 1                False  False        False   NaN               4.809395
# 2                False  False        False   NaN               6.207475
# 3                False  False        False   NaN              80.510765
# 4                False  False        False   NaN               4.045111
# ..                 ...    ...          ...   ...                    ...
# 476              False  False        False   NaN               8.220710
# 477              False  False        False   NaN               0.195731
# 478              False  False        False   NaN               0.382142
# 479              False  False        False   NaN               0.139808
# 480              False  False        False   NaN               0.000000
#
#      glia_detection_rate  combined_detection_rate
# 0               0.000000                 0.000000
# 1               0.646754                 2.728075
# 2               1.462057                 3.834766
# 3              17.544685                49.027725
# 4              11.574945                 7.810028
# ..                   ...                      ...
# 476             0.019599                 4.120154
# 477             0.015679                 0.105705
# 478             0.160709                 0.271425
# 479             0.160709                 0.150258
# 480             0.027438                 0.013719
#
# [475 rows x 15 columns]

# %% [markdown]
# ### Rename genes to mm10 convention after calculating gene detection rate

# %%
# Gene renaming map
#gene_updates = {
#    "Fam19a1": "Tafa1",
#    "Mrgprc11": "Mrgprx1",
#    "Il6r": "Il6ra",
#    "Cyr61": "Ccn1",
#    "2810417H13Rik": "Pclaf",
#    "Fam19a5": "Tafa5",
#    "Abcb1": "Abcb1a"
#}

# Apply renaming
#panel["Gene"] = panel["Gene"].replace(gene_updates)

# %%
filename = Path(output_dir) / "2025-07-11_drg-draft-panel.csv"
#panel.to_csv(filename, index=False)

# %% [markdown]
# # Finishing touches

# %% [markdown]
# Iterative modifications and backup genes:

# %%
panel
# Out:
#          Gene          Ensembl ID  Probesets  zhen_list  spectral_panel  \
# 0       Pdcd1  ENSMUSG00000026285        8.0       True            True
# 1      Adra2a  ENSMUSG00000033717        8.0       True           False
# 2       Il1r1  ENSMUSG00000026072        8.0       True           False
# 3       Il6st  ENSMUSG00000021756        8.0       True           False
# 4    Tnfrsf1a  ENSMUSG00000030341        8.0       True           False
# ..        ...                 ...        ...        ...             ...
# 476     Gata3                 NaN        NaN      False           False
# 477       Il5                 NaN        NaN      False           False
# 478    S100a8                 NaN        NaN      False           False
# 479    S100a9                 NaN        NaN      False           False
# 480      Gfap                 NaN        NaN      False           False
#
#      neurons_supervised  neurons_unsupervised  glia_supervised  \
# 0                 False                 False            False
# 1                 False                 False            False
# 2                 False                 False            False
# 3                 False                 False            False
# 4                 False                 False            False
# ..                  ...                   ...              ...
# 476               False                 False            False
# 477               False                 False            False
# 478               False                 False            False
# 479               False                 False            False
# 480               False                 False            False
#
#      glia_unsupervised  other  neuron_DEGs Notes  neuron_detection_rate  \
# 0                False  False        False   NaN                    NaN
# 1                False  False        False   NaN               4.809395
# 2                False  False        False   NaN               6.207475
# 3                False  False        False   NaN              80.510765
# 4                False  False        False   NaN               4.045111
# ..                 ...    ...          ...   ...                    ...
# 476              False  False        False   NaN               8.220710
# 477              False  False        False   NaN               0.195731
# 478              False  False        False   NaN               0.382142
# 479              False  False        False   NaN               0.139808
# 480              False  False        False   NaN               0.000000
#
#      glia_detection_rate  combined_detection_rate
# 0               0.000000                 0.000000
# 1               0.646754                 2.728075
# 2               1.462057                 3.834766
# 3              17.544685                49.027725
# 4              11.574945                 7.810028
# ..                   ...                      ...
# 476             0.019599                 4.120154
# 477             0.015679                 0.105705
# 478             0.160709                 0.271425
# 479             0.160709                 0.150258
# 480             0.027438                 0.013719
#
# [475 rows x 15 columns]

# %%
genes_to_remove = [
    "Calm1", "Rps15a", "Rps20", "Stmn1", "Dad1", "Hsp90b1", "Xist", "N6amt2", "Tmem261",
    "Aimp1", "Bola1", "Bpgm", "Ccdc25", "Coq7", "Csrp1", "Ctnnb1", "Dad1", "Emp3",
    "Fam216a", "Fkbp2", "Gm1673", "Hmgn3", "Idi1", "Lysmd2", "Lysmd4", "Me1", "Ostf1",
    "Pbdc1", "Pet100", "Pou4f1", "Psmg3", "Psph", "Serinc5", "Serpina3n", "Ubald2", "Id3",
    "Glul", "Tecr", "Tjp1", "Pmvk", "Krcc1", "Dbh", "Mcm3", "Rbfox3", "Chat", "Mrps6",
    "Chrna1", "Gria2", "Tgfbi", "Nr2f2", "mt-Nd6" #"Adrb3", "Gabra2", "Il17rd", "Gja5", 

    # Genes removed 7/8

    ## add_on
    "Il10", "Gfap", "Dlg5", "Gabrb3", "Grin1", "Hey1", "Tubb3", "Mpz", "S100b", "Chrna1", "Chrna7", "Chrna10", "Tie1", "Cdh5", "Apoe", "Cd47", "Cd200", "Dmd", "Fabp7", "Junb",
    "Snap25", "Col1a1",

    ## unsupervised neuron fraction --> problematic
    "Adprh", "Gpm6b", "Hsf2", "Insig1", "Kdm6b", "Mrps28", "Nudt2", "Pdcd4", "Pttg1", "Rbm15", "Rpgrip1", "Sf3b5", "Snrpd1", "Tax1bp3", "Timm9", "Zbtb8os", "Zswim7", "Pim1",

    # unsupervised persist on non neuronal fraction (not problematic but redundancy can be trimmed)
    #"Adamts5", "Cald1", "Dhh", "Ednrb", "Fmo1", "Grrp1", "Rhoc", "Sec11c", "Srsf4", "Ube216"
]

# secondary list --> might want to re-run with an additional five genes from below moved up to genes_to_remove
backup_genes_to_remove = [
    "Tie1",
    "Pecam1",
    "Junb",
    "Egr1",
    "Fosb",
    "Cyr61",
    "Nr4a1",
    "Ly6g",
    "P2ry6",
    "Cd80",
    "Cd86",
    #"Gja5",
    #"Il17rd",
    "Cd200",
    #"Gabra2",
    #"Adrb3",
]

# %%
genes_to_remove = [
    "Calm1", "Rps15a", "Rps20", "Stmn1", "Dad1", "Hsp90b1", "Xist", "N6amt2", "Tmem261",
    "Aimp1", "Bola1", "Bpgm", "Ccdc25", "Coq7", "Csrp1", "Ctnnb1", "Dad1", "Emp3",
    "Fam216a", "Fkbp2", "Gm1673", "Hmgn3", "Idi1", "Lysmd2", "Lysmd4", "Me1", "Ostf1",
    "Pbdc1", "Pet100", "Pou4f1", "Psmg3", "Psph", "Serinc5", "Serpina3n", "Ubald2", "Id3",
    "Glul", "Tecr", "Tjp1", "Pmvk", "Krcc1", "Dbh", "Mcm3", "Rbfox3", "Chat", "Mrps6",
    "Chrna1", "Gria2", "Tgfbi", "Nr2f2", "mt-Nd6" #"Adrb3", "Gabra2", "Il17rd", "Gja5", 

    # Genes removed 7/8

    ## from add_on
    "Il10", "Dlg5", "Gabrb3", "Grin1", "Hey1", "Tubb3", "Mpz", "S100b", "Chrna1", "Chrna7", "Chrna10", "Tie1", "Cdh5", "Apoe", "Cd47", "Cd200", "Dmd", "Junb", # "Fabp7", "Gfap",
    "Snap25", "Col1a1",

    ## unsupervised neuron fraction --> problematic
    "Adprh", "Gpm6b", "Hsf2", "Insig1", "Kdm6b", "Mrps28", "Nudt2", "Pdcd4", "Pttg1", "Rbm15", "Rpgrip1", "Sf3b5", "Snrpd1", "Tax1bp3", "Timm9", "Zbtb8os", "Zswim7", "Pim1",

    # unsupervised persist on non neuronal fraction (not problematic but redundancy can be trimmed)
    #"Adamts5", "Cald1", "Dhh", "Ednrb", "Fmo1", "Grrp1", "Rhoc", "Sec11c", "Srsf4", "Ube216"

    # Genes removed 7/11
    "Tigit", "Il17a", "Prf1", "mt-Nd6", "Cdc20"
]

# %%
# Remove genes
panel_filtered = panel[~panel["Gene"].isin(genes_to_remove)]

# Drop duplicate genes
panel_filtered = panel_filtered.drop_duplicates(subset="Gene", keep="first")

# Count TRUE values in each column
true_counts = panel_filtered.select_dtypes(include=bool).sum()

# Print result
print(true_counts)
# Out:
# zhen_list               114
# spectral_panel           48
# neurons_supervised       49
# neurons_unsupervised     17
# glia_supervised          47
# glia_unsupervised        27
# other                   143
# neuron_DEGs              24
# dtype: int64

# %%
panel_filtered
# Out:
#          Gene          Ensembl ID  Probesets  zhen_list  spectral_panel  \
# 0       Pdcd1  ENSMUSG00000026285        8.0       True            True
# 1      Adra2a  ENSMUSG00000033717        8.0       True           False
# 2       Il1r1  ENSMUSG00000026072        8.0       True           False
# 3       Il6st  ENSMUSG00000021756        8.0       True           False
# 4    Tnfrsf1a  ENSMUSG00000030341        8.0       True           False
# ..        ...                 ...        ...        ...             ...
# 476     Gata3                 NaN        NaN      False           False
# 477       Il5                 NaN        NaN      False           False
# 478    S100a8                 NaN        NaN      False           False
# 479    S100a9                 NaN        NaN      False           False
# 480      Gfap                 NaN        NaN      False           False
#
#      neurons_supervised  neurons_unsupervised  glia_supervised  \
# 0                 False                 False            False
# 1                 False                 False            False
# 2                 False                 False            False
# 3                 False                 False            False
# 4                 False                 False            False
# ..                  ...                   ...              ...
# 476               False                 False            False
# 477               False                 False            False
# 478               False                 False            False
# 479               False                 False            False
# 480               False                 False            False
#
#      glia_unsupervised  other  neuron_DEGs Notes  neuron_detection_rate  \
# 0                False  False        False   NaN                    NaN
# 1                False  False        False   NaN               4.809395
# 2                False  False        False   NaN               6.207475
# 3                False  False        False   NaN              80.510765
# 4                False  False        False   NaN               4.045111
# ..                 ...    ...          ...   ...                    ...
# 476              False  False        False   NaN               8.220710
# 477              False  False        False   NaN               0.195731
# 478              False  False        False   NaN               0.382142
# 479              False  False        False   NaN               0.139808
# 480              False  False        False   NaN               0.000000
#
#      glia_detection_rate  combined_detection_rate
# 0               0.000000                 0.000000
# 1               0.646754                 2.728075
# 2               1.462057                 3.834766
# 3              17.544685                49.027725
# 4              11.574945                 7.810028
# ..                   ...                      ...
# 476             0.019599                 4.120154
# 477             0.015679                 0.105705
# 478             0.160709                 0.271425
# 479             0.160709                 0.150258
# 480             0.027438                 0.013719
#
# [475 rows x 15 columns]

# %%
panel_filtered.loc[panel_filtered['Gene'] == 'S100a9']
# Out:
#        Gene Ensembl ID  Probesets  zhen_list  spectral_panel  \
# 479  S100a9        NaN        NaN      False           False
#
#      neurons_supervised  neurons_unsupervised  glia_supervised  \
# 479               False                 False            False
#
#      glia_unsupervised  other  neuron_DEGs Notes  neuron_detection_rate  \
# 479              False  False        False   NaN               0.139808
#
#      glia_detection_rate  combined_detection_rate
# 479             0.160709                 0.150258

# %%
filename = Path(output_dir) / "2025-07-11_drg-draft-panel-filtered.csv"
#panel_filtered.to_csv(filename, index=False)

# %%
# List of genes to set as True
zhen_genes = ["Siglecf", "Cd200r3", "Itga2", "Gata3", "Thy1", "Il5", "S100a8", "S100a9"]

# Update the 'zhen_list' column based on Gene match
panel_filtered.loc[panel_filtered['Gene'].isin(zhen_genes), 'zhen_list'] = True

# %% [markdown]
# ### Source tally

# %%
plt.rcParams['figure.dpi'] = 300

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Define grouped categories in desired display order
group_map = {
    'Other': ['zhen_list', 'spectral_panel', 'other'],
    'PERSIST - Neurons (supervised)': ['neurons_supervised'],
    'PERSIST - Neurons (unsupervised)': ['neurons_unsupervised'],
    'PERSIST - Glia (supervised)': ['glia_supervised'],
    'PERSIST - Glia (unsupervised)': ['glia_unsupervised'],
    'DEGs': ['neuron_DEGs']
}

# Count genes per group (keep group_map order)
group_tally = {
    group: panel_filtered[cols].any(axis=1).sum()
    for group, cols in group_map.items()
}

# Prepare pie chart data (no sorting)
labels = [
    f"{group}\n{count} genes\n({count/sum(group_tally.values()):.1%})"
    for group, count in group_tally.items()
]
values = list(group_tally.values())

# Set a consistent color palette
colors = sns.color_palette("Set3", n_colors=len(group_tally))

# Plot
plt.figure(figsize=(8, 8))
plt.pie(values, labels=labels, colors=colors, startangle=140)
plt.title("")
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# List of all boolean columns to include individually
columns = [
    'zhen_list',
    'spectral_panel',
    'neurons_supervised',
    'neurons_unsupervised',
    'glia_supervised',
    'glia_unsupervised',
    'other',
    'neuron_DEGs'
]

# Count number of genes where each column is True
tally = {col: panel_filtered[col].sum() for col in columns}

# Build labels
total = sum(tally.values())
labels = [
    f"{col}\n{count} genes\n({count/total:.1%})"
    for col, count in tally.items()
]
values = list(tally.values())

# Use a good color palette
colors = sns.color_palette("Set3", n_colors=len(columns))

# Plot pie chart
plt.figure(figsize=(8, 8))
plt.pie(values, labels=labels, colors=colors, startangle=140)
plt.title("Gene Counts by Individual Annotation", fontsize=14)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Session info

# %%
import os
print('active IDE: sc-sq-gpu')
print('active conda environment:', os.path.basename(sys.prefix))
session_info.show()
# Out:
# active IDE: sc-sq-gpu
# active conda environment: sc-spatial
# <details>
# <summary>Click to view session information</summary>
# <pre>
# -----
# anndata             0.10.6
# matplotlib          3.8.3
# numpy               1.26.4
# pandas              2.2.1
# scanpy              1.9.8
# scipy               1.12.0
# session_info        1.0.0
# -----
# </pre>
# <details>
# <summary>Click to view modules imported as dependencies</summary>
# <pre>
# PIL                         10.2.0
# anyio                       NA
# arrow                       1.3.0
# asciitree                   NA
# asttokens                   NA
# attr                        23.2.0
# attrs                       23.2.0
# babel                       2.14.0
# brotli                      1.1.0
# certifi                     2024.06.02
# cffi                        1.16.0
# charset_normalizer          3.3.2
# cloudpickle                 3.0.0
# colorama                    0.4.6
# comm                        0.2.2
# cycler                      0.12.1
# cython_runtime              NA
# cytoolz                     0.12.3
# dask                        2024.3.1
# dateutil                    2.9.0
# debugpy                     1.8.1
# decorator                   5.1.1
# defusedxml                  0.7.1
# executing                   2.0.1
# fastjsonschema              NA
# fqdn                        NA
# h5py                        3.10.0
# idna                        3.6
# igraph                      0.11.4
# ipykernel                   6.29.3
# isoduration                 NA
# jedi                        0.19.1
# jinja2                      3.1.3
# joblib                      1.3.2
# json5                       0.9.24
# jsonpointer                 2.4
# jsonschema                  4.21.1
# jsonschema_specifications   NA
# jupyter_events              0.10.0
# jupyter_server              2.13.0
# jupyterlab_server           2.25.4
# kiwisolver                  1.4.5
# leidenalg                   0.10.2
# llvmlite                    0.42.0
# lz4                         4.3.3
# markupsafe                  2.1.5
# matplotlib_inline           0.1.6
# mpl_toolkits                NA
# mpmath                      1.3.0
# msgpack                     1.0.7
# natsort                     8.4.0
# nbformat                    5.10.3
# numba                       0.59.1
# numcodecs                   0.12.1
# overrides                   NA
# packaging                   24.0
# parso                       0.8.3
# pickleshare                 0.7.5
# platformdirs                4.2.0
# plotly                      5.20.0
# prometheus_client           NA
# prompt_toolkit              3.0.42
# psutil                      5.9.8
# pure_eval                   0.2.2
# pyarrow                     15.0.0
# pydev_ipython               NA
# pydevconsole                NA
# pydevd                      2.9.5
# pydevd_file_utils           NA
# pydevd_plugins              NA
# pydevd_tracing              NA
# pygments                    2.17.2
# pyparsing                   3.1.2
# pythonjsonlogger            NA
# pytz                        2024.1
# referencing                 NA
# requests                    2.31.0
# rfc3339_validator           0.1.4
# rfc3986_validator           0.1.1
# rpds                        NA
# send2trash                  NA
# six                         1.16.0
# sklearn                     1.4.1.post1
# sniffio                     1.3.1
# socks                       1.7.1
# sparse                      0.15.1
# stack_data                  0.6.2
# sympy                       1.12
# tblib                       3.0.0
# texttable                   1.7.0
# threadpoolctl               3.4.0
# tlz                         0.12.3
# toolz                       0.12.1
# torch                       2.1.2.post3
# torchgen                    NA
# tornado                     6.4
# tqdm                        4.66.2
# traitlets                   5.14.2
# typing_extensions           NA
# uri_template                NA
# urllib3                     2.2.1
# wcwidth                     0.2.13
# webcolors                   1.13
# websocket                   1.7.0
# yaml                        6.0.1
# zarr                        2.17.1
# zmq                         25.1.2
# </pre>
# </details> <!-- seems like this ends pre, so might as well be explicit -->
# <pre>
# -----
# IPython             8.22.2
# jupyter_client      8.6.1
# jupyter_core        5.7.2
# jupyterlab          4.1.5
# notebook            7.1.2
# -----
# Python 3.12.2 | packaged by conda-forge | (main, Feb 16 2024, 20:50:58) [GCC 12.3.0]
# Linux-6.6.72+-x86_64-with-glibc2.35
# -----
# Session information updated at 2025-07-11 12:11
# </pre>
# </details>

# %%
#sc.pl.umap(bdata, color = ['Col3a1', 'Apoe', 'Fabp7', 'Mbp', 'Mpz'], frameon = False, ncols = 5)
