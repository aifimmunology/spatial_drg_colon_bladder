# %%
from datetime import datetime

print(f"Timestamp: {datetime.now()}")
# Out:
# Timestamp: 2025-12-02 10:41:11.234883

# %% [markdown]
# # Create AnnData from Xenium output folders

# %%
import sys
from pathlib import Path
import os
import numpy as np
import pandas as pd
import anndata as ad
import scanpy as sc
import squidpy as sq
import matplotlib.pyplot as plt
import seaborn as sns
import math
import session_info

# %%
plt.rcParams['figure.dpi'] = 150

# %% [markdown]
# ## Set paths

# %%
base_dir = Path('/home/workspace/projects/drg')

data_input_folder = base_dir / 'download/isolon'
fig_dir = base_dir / 'figures/qc'
h5ad_dir = base_dir / 'data/h5ad/export_01/01a_raw/output_folder'
metadata_dir = base_dir / 'metadata'

# Create directories
base_dir.mkdir(parents=True, exist_ok=True)
fig_dir.mkdir(parents=True, exist_ok=True)
h5ad_dir.mkdir(parents=True, exist_ok=True)
metadata_dir.mkdir(parents=True, exist_ok=True)

# %%
sample_id_mapping = {
    "output-XETG00123__0052281__TMA00303__20251108__004334": "TMA00303",
    "output-XETG00123__0052334__TMA00304__20251108__004334": "TMA00304",
    "output-XETG00123__0052281__TMA00305__20251108__004334": "TMA00305",
    "output-XETG00123__0052334__TMA00306__20251108__004334": "TMA00306",
    "output-XETG00123__0052046__TMA00307__20251119__221941": "TMA00307",
    "output-XETG00123__0052399__TMA00308__20251119__221941": "TMA00308",
    "output-XETG00123__0052046__TMA00311__20251119__221941": "TMA00311",
    "output-XETG00123__0052399__TMA00312__20251119__221941": "TMA00312"
}

# %%
sample_id_mapping = {
    "output-XETG00123__0052281__TMA00303__20251108__004334": {"region": "TMA00303", "slide": "0052281"},
    "output-XETG00123__0052334__TMA00304__20251108__004334": {"region": "TMA00304", "slide": "0052334"},
    "output-XETG00123__0052281__TMA00305__20251108__004334": {"region": "TMA00305", "slide": "0052281"},
    "output-XETG00123__0052334__TMA00306__20251108__004334": {"region": "TMA00306", "slide": "0052334"},
    "output-XETG00123__0052046__TMA00307__20251119__221941": {"region": "TMA00307", "slide": "0052046"},
    "output-XETG00123__0052399__TMA00308__20251119__221941": {"region": "TMA00308", "slide": "0052399"},
    "output-XETG00123__0052046__TMA00311__20251119__221941": {"region": "TMA00311", "slide": "0052046"},
    "output-XETG00123__0052399__TMA00312__20251119__221941": {"region": "TMA00312", "slide": "0052399"},
}

# %% [markdown]
# ## Functions

# %%
def h5_to_adata(directory, sample_id):
    # File names    
    h5_file = os.path.join(directory, 'cell_feature_matrix.h5')
    cells_file = os.path.join(directory, 'cells.csv.gz')

    # h5 to adata
    adata = sc.read_10x_h5(
        filename=h5_file
    )

    # cells file
    df = pd.read_csv(
        cells_file, 
        compression='gzip'
    )

    # Set index
    df.set_index(adata.obs_names, inplace=True)
    adata.obs = df.copy()

    # x, y coordinates
    adata.obsm["spatial"] = adata.obs[["x_centroid", "y_centroid"]].copy().to_numpy()

    # Add sample metadata
    adata.obs['sample_id'] = sample_id

    return adata

# %% [markdown]
# ## Create sample dictionary

# %%
directory_to_sample = {
    os.path.join(data_input_folder, subdir): f"{subdir}"
    for subdir in os.listdir(data_input_folder) if os.path.isdir(os.path.join(data_input_folder, subdir))
    if os.path.isdir(os.path.join(data_input_folder, subdir)) and not subdir.startswith(".")  # Excludes hidden folders like .ipynb_checkpoints
}

print(directory_to_sample)
# Out:
# {'/home/workspace/projects/drg/download/isolon/output-XETG00123__0052399__TMA00312__20251119__221941': 'output-XETG00123__0052399__TMA00312__20251119__221941', '/home/workspace/projects/drg/download/isolon/output-XETG00123__0052281__TMA00305__20251108__004334': 'output-XETG00123__0052281__TMA00305__20251108__004334', '/home/workspace/projects/drg/download/isolon/output-XETG00123__0052399__TMA00308__20251119__221941': 'output-XETG00123__0052399__TMA00308__20251119__221941', '/home/workspace/projects/drg/download/isolon/output-XETG00123__0052281__TMA00303__20251108__004334': 'output-XETG00123__0052281__TMA00303__20251108__004334', '/home/workspace/projects/drg/download/isolon/output-XETG00123__0052334__TMA00304__20251108__004334': 'output-XETG00123__0052334__TMA00304__20251108__004334', '/home/workspace/projects/drg/download/isolon/output-XETG00123__0052046__TMA00311__20251119__221941': 'output-XETG00123__0052046__TMA00311__20251119__221941', '/home/workspace/projects/drg/download/isolon/output-XETG00123__0052334__TMA00306__20251108__004334': 'output-XETG00123__0052334__TMA00306__20251108__004334', '/home/workspace/projects/drg/download/isolon/output-XETG00123__0052046__TMA00307__20251119__221941': 'output-XETG00123__0052046__TMA00307__20251119__221941'}

# %% [markdown]
# ## Create anndata

# %%
# Loop through each key-value pair in the dictionary
adata_list = []
for directory, output_id in directory_to_sample.items():
    print(f"Processing: {directory} -> Run ID: {output_id}")
    adata = h5_to_adata(directory, output_id)
    adata.obs["output_id"] = output_id  
    adata_list.append(adata)
# Out:
# Processing: /home/workspace/projects/drg/download/isolon/output-XETG00123__0052399__TMA00312__20251119__221941 -> Run ID: output-XETG00123__0052399__TMA00312__20251119__221941
# Processing: /home/workspace/projects/drg/download/isolon/output-XETG00123__0052281__TMA00305__20251108__004334 -> Run ID: output-XETG00123__0052281__TMA00305__20251108__004334
# Processing: /home/workspace/projects/drg/download/isolon/output-XETG00123__0052399__TMA00308__20251119__221941 -> Run ID: output-XETG00123__0052399__TMA00308__20251119__221941
# Processing: /home/workspace/projects/drg/download/isolon/output-XETG00123__0052281__TMA00303__20251108__004334 -> Run ID: output-XETG00123__0052281__TMA00303__20251108__004334
# Processing: /home/workspace/projects/drg/download/isolon/output-XETG00123__0052334__TMA00304__20251108__004334 -> Run ID: output-XETG00123__0052334__TMA00304__20251108__004334
# Processing: /home/workspace/projects/drg/download/isolon/output-XETG00123__0052046__TMA00311__20251119__221941 -> Run ID: output-XETG00123__0052046__TMA00311__20251119__221941
# Processing: /home/workspace/projects/drg/download/isolon/output-XETG00123__0052334__TMA00306__20251108__004334 -> Run ID: output-XETG00123__0052334__TMA00306__20251108__004334
# Processing: /home/workspace/projects/drg/download/isolon/output-XETG00123__0052046__TMA00307__20251119__221941 -> Run ID: output-XETG00123__0052046__TMA00307__20251119__221941

# %%
for adata in adata_list:
    adata.obs["sample_id"] = adata.obs["output_id"].map(lambda x: sample_id_mapping[x]["region"])
    adata.obs["region_id"] = adata.obs["sample_id"]
    adata.obs["slide_id"]  = adata.obs["output_id"].map(lambda x: sample_id_mapping[x]["slide"])

    print(adata.obs[["output_id", "sample_id", "region_id", "slide_id"]].head(1))
# Out:
#                                                     output_id sample_id  \
# aaaijnlc-1  output-XETG00123__0052399__TMA00312__20251119_...  TMA00312
#
#            region_id slide_id
# aaaijnlc-1  TMA00312  0052399
#                                                     output_id sample_id  \
# aaaaicce-1  output-XETG00123__0052281__TMA00305__20251108_...  TMA00305
#
#            region_id slide_id
# aaaaicce-1  TMA00305  0052281
#                                                     output_id sample_id  \
# aaabcimg-1  output-XETG00123__0052399__TMA00308__20251119_...  TMA00308
#
#            region_id slide_id
# aaabcimg-1  TMA00308  0052399
#                                                     output_id sample_id  \
# aaagciof-1  output-XETG00123__0052281__TMA00303__20251108_...  TMA00303
#
#            region_id slide_id
# aaagciof-1  TMA00303  0052281
#                                                     output_id sample_id  \
# aaacpmhc-1  output-XETG00123__0052334__TMA00304__20251108_...  TMA00304
#
#            region_id slide_id
# aaacpmhc-1  TMA00304  0052334
#                                                     output_id sample_id  \
# aaabeogo-1  output-XETG00123__0052046__TMA00311__20251119_...  TMA00311
#
#            region_id slide_id
# aaabeogo-1  TMA00311  0052046
#                                                     output_id sample_id  \
# aaaackia-1  output-XETG00123__0052334__TMA00306__20251108_...  TMA00306
#
#            region_id slide_id
# aaaackia-1  TMA00306  0052334
#                                                     output_id sample_id  \
# aabdcfle-1  output-XETG00123__0052046__TMA00307__20251119_...  TMA00307
#
#            region_id slide_id
# aabdcfle-1  TMA00307  0052046

# %% [markdown]
# ## QC

# %%
adata_list
# Out:
# [AnnData object with n_obs × n_vars = 21826 × 480
#      obs: 'cell_id', 'x_centroid', 'y_centroid', 'transcript_counts', 'control_probe_counts', 'genomic_control_counts', 'control_codeword_counts', 'unassigned_codeword_counts', 'deprecated_codeword_counts', 'total_counts', 'cell_area', 'nucleus_area', 'nucleus_count', 'segmentation_method', 'sample_id', 'output_id', 'region_id', 'slide_id'
#      var: 'gene_ids', 'feature_types', 'genome'
#      obsm: 'spatial',
#  AnnData object with n_obs × n_vars = 38753 × 480
#      obs: 'cell_id', 'x_centroid', 'y_centroid', 'transcript_counts', 'control_probe_counts', 'genomic_control_counts', 'control_codeword_counts', 'unassigned_codeword_counts', 'deprecated_codeword_counts', 'total_counts', 'cell_area', 'nucleus_area', 'nucleus_count', 'segmentation_method', 'sample_id', 'output_id', 'region_id', 'slide_id'
#      var: 'gene_ids', 'feature_types', 'genome'
#      obsm: 'spatial',
#  AnnData object with n_obs × n_vars = 9759 × 480
#      obs: 'cell_id', 'x_centroid', 'y_centroid', 'transcript_counts', 'control_probe_counts', 'genomic_control_counts', 'control_codeword_counts', 'unassigned_codeword_counts', 'deprecated_codeword_counts', 'total_counts', 'cell_area', 'nucleus_area', 'nucleus_count', 'segmentation_method', 'sample_id', 'output_id', 'region_id', 'slide_id'
#      var: 'gene_ids', 'feature_types', 'genome'
#      obsm: 'spatial',
#  AnnData object with n_obs × n_vars = 12755 × 480
#      obs: 'cell_id', 'x_centroid', 'y_centroid', 'transcript_counts', 'control_probe_counts', 'genomic_control_counts', 'control_codeword_counts', 'unassigned_codeword_counts', 'deprecated_codeword_counts', 'total_counts', 'cell_area', 'nucleus_area', 'nucleus_count', 'segmentation_method', 'sample_id', 'output_id', 'region_id', 'slide_id'
#      var: 'gene_ids', 'feature_types', 'genome'
#      obsm: 'spatial',
#  AnnData object with n_obs × n_vars = 24375 × 480
#      obs: 'cell_id', 'x_centroid', 'y_centroid', 'transcript_counts', 'control_probe_counts', 'genomic_control_counts', 'control_codeword_counts', 'unassigned_codeword_counts', 'deprecated_codeword_counts', 'total_counts', 'cell_area', 'nucleus_area', 'nucleus_count', 'segmentation_method', 'sample_id', 'output_id', 'region_id', 'slide_id'
#      var: 'gene_ids', 'feature_types', 'genome'
#      obsm: 'spatial',
#  AnnData object with n_obs × n_vars = 24803 × 480
#      obs: 'cell_id', 'x_centroid', 'y_centroid', 'transcript_counts', 'control_probe_counts', 'genomic_control_counts', 'control_codeword_counts', 'unassigned_codeword_counts', 'deprecated_codeword_counts', 'total_counts', 'cell_area', 'nucleus_area', 'nucleus_count', 'segmentation_method', 'sample_id', 'output_id', 'region_id', 'slide_id'
#      var: 'gene_ids', 'feature_types', 'genome'
#      obsm: 'spatial',
#  AnnData object with n_obs × n_vars = 37315 × 480
#      obs: 'cell_id', 'x_centroid', 'y_centroid', 'transcript_counts', 'control_probe_counts', 'genomic_control_counts', 'control_codeword_counts', 'unassigned_codeword_counts', 'deprecated_codeword_counts', 'total_counts', 'cell_area', 'nucleus_area', 'nucleus_count', 'segmentation_method', 'sample_id', 'output_id', 'region_id', 'slide_id'
#      var: 'gene_ids', 'feature_types', 'genome'
#      obsm: 'spatial',
#  AnnData object with n_obs × n_vars = 9238 × 480
#      obs: 'cell_id', 'x_centroid', 'y_centroid', 'transcript_counts', 'control_probe_counts', 'genomic_control_counts', 'control_codeword_counts', 'unassigned_codeword_counts', 'deprecated_codeword_counts', 'total_counts', 'cell_area', 'nucleus_area', 'nucleus_count', 'segmentation_method', 'sample_id', 'output_id', 'region_id', 'slide_id'
#      var: 'gene_ids', 'feature_types', 'genome'
#      obsm: 'spatial']

# %% [markdown]
# #### Fix order

# %%
adata_list = sorted(adata_list, key=lambda ad: ad.obs["sample_id"].iloc[0])

# %% [markdown]
# #### Visualize

# %%
for adata in adata_list:
    sample_id = adata.obs['sample_id'].iloc[0]
    print(sample_id)

    # Calculate QC
    sc.pp.calculate_qc_metrics(adata, percent_top=(10, 20, 50, 150), inplace=True)

    # Number of cells
    cell_num = adata.obs.shape[0]
    print(cell_num, 'cells')

    # Visualize QC
    fig, axs = plt.subplots(1, 2, figsize=(15, 4))

    # Plot the first histogram: Total Counts
    counts_median = adata.obs["total_counts"].median()  
    axs[0].hist(adata.obs["total_counts"], bins=math.ceil(cell_num / 50), edgecolor='black')
    axs[0].set_title(sample_id + ", " + "counts/cell")
    axs[0].set_xlim(0, 1500)
    axs[0].set_ylim(0, 3000)
    axs[0].set_xlabel('Total Counts')
    axs[0].set_ylabel('Frequency')
    axs[0].axvline(counts_median, color='red', linestyle='--', label=f'Median: {counts_median:.2f}')  # Add vertical line
    axs[0].legend()  # Add legend for the median line

    # Plot the second histogram: Genes by Counts
    genes_median = adata.obs["n_genes_by_counts"].median()  
    axs[1].hist(adata.obs["n_genes_by_counts"], bins=math.ceil(cell_num / 50), edgecolor='black')
    axs[1].set_title(sample_id + ", " + "genes/cell")
    axs[1].set_xlim(0, 300)
    axs[1].set_xlabel('Unique Transcripts (genes)')
    axs[1].set_ylabel('Frequency')
    axs[1].axvline(genes_median, color='red', linestyle='--', label=f'Median: {genes_median:.2f}')  # Add vertical line
    axs[1].legend()  # Add legend for the median line

    # Save figure
    fig.savefig(os.path.join(fig_dir, sample_id + '_raw_QC.png'))
# Out:
# TMA00303
# 12755 cells
# TMA00304
# 24375 cells
# TMA00305
# 38753 cells
# TMA00306
# 37315 cells
# TMA00307
# 9238 cells
# TMA00308
# 9759 cells
# TMA00311
# 24803 cells
# TMA00312
# 21826 cells

# %% [markdown]
# ## Genes of interest

# %%
genes = adata.var
genes.head()
# Out:
#                          gene_ids    feature_types   genome  \
# 1500009L16Rik  ENSMUSG00000087651  Gene Expression  Unknown
# 6330403K07Rik  ENSMUSG00000018451  Gene Expression  Unknown
# Abcb1a         ENSMUSG00000040584  Gene Expression  Unknown
# Ache           ENSMUSG00000023328  Gene Expression  Unknown
# Acta2          ENSMUSG00000035783  Gene Expression  Unknown
#
#                n_cells_by_counts  mean_counts  log1p_mean_counts  \
# 1500009L16Rik               1109     0.069138           0.066852
# 6330403K07Rik               6503     3.656740           1.538316
# Abcb1a                      3668     0.413223           0.345873
# Ache                        5054     1.249473           0.810696
# Acta2                        736     0.047924           0.046812
#
#                pct_dropout_by_counts  total_counts  log1p_total_counts
# 1500009L16Rik              94.918904        1509.0            7.319865
# 6330403K07Rik              70.205260       79812.0           11.287441
# Abcb1a                     83.194355        9019.0            9.107200
# Ache                       76.844131       27271.0           10.213615
# Acta2                      96.627875        1046.0            6.953684

# %%
# save panel
csv_path = os.path.join(metadata_dir, 'gene-panel.csv')
genes.to_csv(csv_path, index = True)

print(f'Gene panel saved at: {csv_path}')
# Out:
# Gene panel saved at: /home/workspace/projects/drg/metadata/gene-panel.csv

# %% [markdown]
# ## Export Anndata

# %%
# export 01

for i, adata in enumerate(adata_list):
    sample_name = adata.obs["sample_id"][0] if "sample_id" in adata.obs.columns else f"sample_{i+1}"
    output_file = os.path.join(h5ad_dir, f"{sample_name}.h5ad")
    
    adata.write(output_file)
    print(f"Saved: {output_file}")
# Out:
# Saved: /home/workspace/projects/drg/data/h5ad/export_01/01a_raw/output_folder/TMA00303.h5ad
# /tmp/ipykernel_6863/2863077922.py:4: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   sample_name = adata.obs["sample_id"][0] if "sample_id" in adata.obs.columns else f"sample_{i+1}"
# /tmp/ipykernel_6863/2863077922.py:4: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   sample_name = adata.obs["sample_id"][0] if "sample_id" in adata.obs.columns else f"sample_{i+1}"
# Saved: /home/workspace/projects/drg/data/h5ad/export_01/01a_raw/output_folder/TMA00304.h5ad
# Saved: /home/workspace/projects/drg/data/h5ad/export_01/01a_raw/output_folder/TMA00305.h5ad
# /tmp/ipykernel_6863/2863077922.py:4: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   sample_name = adata.obs["sample_id"][0] if "sample_id" in adata.obs.columns else f"sample_{i+1}"
# /tmp/ipykernel_6863/2863077922.py:4: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   sample_name = adata.obs["sample_id"][0] if "sample_id" in adata.obs.columns else f"sample_{i+1}"
# Saved: /home/workspace/projects/drg/data/h5ad/export_01/01a_raw/output_folder/TMA00306.h5ad
# Saved: /home/workspace/projects/drg/data/h5ad/export_01/01a_raw/output_folder/TMA00307.h5ad
# Saved: /home/workspace/projects/drg/data/h5ad/export_01/01a_raw/output_folder/TMA00308.h5ad
# /tmp/ipykernel_6863/2863077922.py:4: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   sample_name = adata.obs["sample_id"][0] if "sample_id" in adata.obs.columns else f"sample_{i+1}"
# /tmp/ipykernel_6863/2863077922.py:4: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   sample_name = adata.obs["sample_id"][0] if "sample_id" in adata.obs.columns else f"sample_{i+1}"
# /tmp/ipykernel_6863/2863077922.py:4: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   sample_name = adata.obs["sample_id"][0] if "sample_id" in adata.obs.columns else f"sample_{i+1}"
# Saved: /home/workspace/projects/drg/data/h5ad/export_01/01a_raw/output_folder/TMA00311.h5ad
# Saved: /home/workspace/projects/drg/data/h5ad/export_01/01a_raw/output_folder/TMA00312.h5ad
# /tmp/ipykernel_6863/2863077922.py:4: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   sample_name = adata.obs["sample_id"][0] if "sample_id" in adata.obs.columns else f"sample_{i+1}"

# %% [markdown]
# ### Session info

# %%
print('active conda environment:', os.path.basename(sys.prefix))
session_info.show()
# Out:
# active conda environment: sc-spatial
# <details>
# <summary>Click to view session information</summary>
# <pre>
# -----
# anndata             0.10.6
# matplotlib          3.8.3
# numpy               1.26.4
# pandas              2.2.1
# scanpy              1.9.8
# seaborn             0.13.2
# session_info        1.0.0
# squidpy             1.2.2
# -----
# </pre>
# <details>
# <summary>Click to view modules imported as dependencies</summary>
# <pre>
# PIL                         10.2.0
# PyQt5                       NA
# anyio                       NA
# arrow                       1.3.0
# asciitree                   NA
# asttokens                   NA
# attr                        23.2.0
# attrs                       23.2.0
# babel                       2.14.0
# brotli                      1.1.0
# certifi                     2024.06.02
# cffi                        1.16.0
# charset_normalizer          3.3.2
# cloudpickle                 3.0.0
# colorama                    0.4.6
# comm                        0.2.2
# cycler                      0.12.1
# cython_runtime              NA
# cytoolz                     0.12.3
# dask                        2024.3.1
# dask_image                  2023.08.1
# dateutil                    2.9.0
# debugpy                     1.8.1
# decorator                   5.1.1
# defusedxml                  0.7.1
# docrep                      0.3.2
# executing                   2.0.1
# fastjsonschema              NA
# fqdn                        NA
# h5py                        3.10.0
# idna                        3.6
# igraph                      0.11.4
# imagecodecs                 2024.1.1
# imageio                     2.34.0
# importlib_metadata          NA
# ipykernel                   6.29.3
# ipywidgets                  8.1.2
# isoduration                 NA
# jedi                        0.19.1
# jinja2                      3.1.3
# joblib                      1.3.2
# json5                       0.9.24
# jsonpointer                 2.4
# jsonschema                  4.21.1
# jsonschema_specifications   NA
# jupyter_events              0.10.0
# jupyter_server              2.13.0
# jupyterlab_server           2.25.4
# kiwisolver                  1.4.5
# lazy_loader                 NA
# leidenalg                   0.10.2
# llvmlite                    0.42.0
# lz4                         4.3.3
# markupsafe                  2.1.5
# matplotlib_inline           0.1.6
# matplotlib_scalebar         0.8.1
# mpl_toolkits                NA
# mpmath                      1.3.0
# msgpack                     1.0.7
# natsort                     8.4.0
# nbformat                    5.10.3
# networkx                    3.2.1
# numba                       0.59.1
# numcodecs                   0.12.1
# overrides                   NA
# packaging                   24.0
# parso                       0.8.3
# patsy                       0.5.6
# pickleshare                 0.7.5
# platformdirs                4.2.0
# plotly                      5.20.0
# prometheus_client           NA
# prompt_toolkit              3.0.42
# psutil                      5.9.8
# pure_eval                   0.2.2
# pyarrow                     15.0.0
# pycparser                   2.21
# pydev_ipython               NA
# pydevconsole                NA
# pydevd                      2.9.5
# pydevd_file_utils           NA
# pydevd_plugins              NA
# pydevd_tracing              NA
# pygments                    2.17.2
# pyparsing                   3.1.2
# pythonjsonlogger            NA
# pytz                        2024.1
# referencing                 NA
# requests                    2.31.0
# rfc3339_validator           0.1.4
# rfc3986_validator           0.1.1
# rpds                        NA
# scipy                       1.12.0
# send2trash                  NA
# sip                         NA
# six                         1.16.0
# skimage                     0.22.0
# sklearn                     1.4.1.post1
# sniffio                     1.3.1
# socks                       1.7.1
# sparse                      0.15.1
# stack_data                  0.6.2
# statsmodels                 0.14.1
# sympy                       1.12
# tblib                       3.0.0
# texttable                   1.7.0
# threadpoolctl               3.4.0
# tifffile                    2024.2.12
# tlz                         0.12.3
# toolz                       0.12.1
# torch                       2.1.2.post3
# torchgen                    NA
# tornado                     6.4
# tqdm                        4.66.2
# traitlets                   5.14.2
# typing_extensions           NA
# uri_template                NA
# urllib3                     2.2.1
# validators                  0.24.0
# wcwidth                     0.2.13
# webcolors                   1.13
# websocket                   1.7.0
# xarray                      2024.2.0
# yaml                        6.0.1
# zarr                        2.17.1
# zipp                        NA
# zmq                         25.1.2
# </pre>
# </details> <!-- seems like this ends pre, so might as well be explicit -->
# <pre>
# -----
# IPython             8.22.2
# jupyter_client      8.6.1
# jupyter_core        5.7.2
# jupyterlab          4.1.5
# notebook            7.1.2
# -----
# Python 3.12.2 | packaged by conda-forge | (main, Feb 16 2024, 20:50:58) [GCC 12.3.0]
# Linux-6.6.87+-x86_64-with-glibc2.35
# -----
# Session information updated at 2025-12-02 10:41
# </pre>
# </details>
