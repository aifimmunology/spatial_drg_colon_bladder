# %% [markdown]
# # GSE139088 clustering

# %%
import time
from pathlib import Path
import pandas as pd
import scanpy as sc
import anndata as ad
from matplotlib import pyplot as plt
import re
import sys
import session_info

# %%
plt.rcParams['figure.figsize'] = (3,3)
#plt.rcParams['figure.dpi'] = 500

# %%
# Directories
base_dir = Path("/home/workspace/private/projects/kim/drg")
data_dir = base_dir / "data" / "scrna-seq"
input_dir = data_dir / "h5ad" / "03_scvi"

h5ad_out_dir = data_dir / "h5ad" / "04_clustered"
h5ad_out_dir.mkdir(parents=True, exist_ok=True)

# %%
input_adata = input_dir / "GSE139088.h5ad"
h5ad_out = h5ad_out_dir / "GSE139088-scvi-leiden.h5ad"

# %%
adata = sc.read_h5ad(input_dir / "GSE139088-scvi.h5ad")

# %%
adata.obs
# Out:
#                                       original_annotation        GSE  \
# GSM4130750_AAACCTGTCTGCTGCT-1                  CGRP-Theta  GSE139088
# GSM4130750_AAACGGGAGTACGCGA-1                  CGRP-Gamma  GSE139088
# GSM4130750_AAACGGGCAGGGATTG-1                  CGRP-Alpha  GSE139088
# GSM4130750_AAACGGGCATTGCGGC-1                  CGRP-Alpha  GSE139088
# GSM4130750_AAACGGGGTGGGTATG-1  Nonpeptidergic nociceptors  GSE139088
# ...                                                   ...        ...
# GSM4130750_CCACTACAGATGCCAG-6                 Abeta-Field  GSE139088
# GSM4130750_CCAGCGAAGCTAGCCC-6                  CGRP-Alpha  GSE139088
# GSM4130750_CCAGCGAAGTGGAGTC-6  Nonpeptidergic nociceptors  GSE139088
# GSM4130750_CCAGCGACAAGAGTCG-6                      C-LTMR  GSE139088
# GSM4130750_CCAGCGACACATCTTT-6                  CGRP-Alpha  GSE139088
#
#                                       GSM  sample_number    sample_id  \
# GSM4130750_AAACCTGTCTGCTGCT-1  GSM4130750              1  GSE139088_1
# GSM4130750_AAACGGGAGTACGCGA-1  GSM4130750              1  GSE139088_1
# GSM4130750_AAACGGGCAGGGATTG-1  GSM4130750              1  GSE139088_1
# GSM4130750_AAACGGGCATTGCGGC-1  GSM4130750              1  GSE139088_1
# GSM4130750_AAACGGGGTGGGTATG-1  GSM4130750              1  GSE139088_1
# ...                                   ...            ...          ...
# GSM4130750_CCACTACAGATGCCAG-6  GSM4130750              6  GSE139088_6
# GSM4130750_CCAGCGAAGCTAGCCC-6  GSM4130750              6  GSE139088_6
# GSM4130750_CCAGCGAAGTGGAGTC-6  GSM4130750              6  GSE139088_6
# GSM4130750_CCAGCGACAAGAGTCG-6  GSM4130750              6  GSE139088_6
# GSM4130750_CCAGCGACACATCTTT-6  GSM4130750              6  GSE139088_6
#
#                               experiment_id  n_genes_by_counts  total_counts  \
# GSM4130750_AAACCTGTCTGCTGCT-1     GSE139088               2523        6931.0
# GSM4130750_AAACGGGAGTACGCGA-1     GSE139088               5212       19993.0
# GSM4130750_AAACGGGCAGGGATTG-1     GSE139088               4349       13737.0
# GSM4130750_AAACGGGCATTGCGGC-1     GSE139088               4747       18238.0
# GSM4130750_AAACGGGGTGGGTATG-1     GSE139088               4670       20604.0
# ...                                     ...                ...           ...
# GSM4130750_CCACTACAGATGCCAG-6     GSE139088               3008        7677.0
# GSM4130750_CCAGCGAAGCTAGCCC-6     GSE139088               3811       10125.0
# GSM4130750_CCAGCGAAGTGGAGTC-6     GSE139088               4833       21559.0
# GSM4130750_CCAGCGACAAGAGTCG-6     GSE139088               4843       17804.0
# GSM4130750_CCAGCGACACATCTTT-6     GSE139088               3466        9487.0
#
#                                total_counts_mt  pct_counts_mt  \
# GSM4130750_AAACCTGTCTGCTGCT-1            134.0       1.933343
# GSM4130750_AAACGGGAGTACGCGA-1            430.0       2.150753
# GSM4130750_AAACGGGCAGGGATTG-1            576.0       4.193055
# GSM4130750_AAACGGGCATTGCGGC-1            490.0       2.686698
# GSM4130750_AAACGGGGTGGGTATG-1            514.0       2.494661
# ...                                        ...            ...
# GSM4130750_CCACTACAGATGCCAG-6            168.0       2.188355
# GSM4130750_CCAGCGAAGCTAGCCC-6            412.0       4.069136
# GSM4130750_CCAGCGAAGTGGAGTC-6            692.0       3.209796
# GSM4130750_CCAGCGACAAGAGTCG-6            835.0       4.689957
# GSM4130750_CCAGCGACACATCTTT-6            278.0       2.930326
#
#                                total_counts_ribosomal  pct_counts_ribosomal  \
# GSM4130750_AAACCTGTCTGCTGCT-1                   326.0              4.703506
# GSM4130750_AAACGGGAGTACGCGA-1                  1430.0              7.152503
# GSM4130750_AAACGGGCAGGGATTG-1                  1143.0              8.320594
# GSM4130750_AAACGGGCATTGCGGC-1                  1593.0              8.734510
# GSM4130750_AAACGGGGTGGGTATG-1                  1450.0              7.037468
# ...                                               ...                   ...
# GSM4130750_CCACTACAGATGCCAG-6                   381.0              4.962876
# GSM4130750_CCAGCGAAGCTAGCCC-6                   948.0              9.362963
# GSM4130750_CCAGCGAAGTGGAGTC-6                  2056.0              9.536620
# GSM4130750_CCAGCGACAAGAGTCG-6                  1185.0              6.655808
# GSM4130750_CCAGCGACACATCTTT-6                   914.0              9.634236
#
#                                doublet_scores  predicted_doublets  \
# GSM4130750_AAACCTGTCTGCTGCT-1        0.070248               False
# GSM4130750_AAACGGGAGTACGCGA-1        0.044776               False
# GSM4130750_AAACGGGCAGGGATTG-1        0.025710               False
# GSM4130750_AAACGGGCATTGCGGC-1        0.036697               False
# GSM4130750_AAACGGGGTGGGTATG-1        0.036697               False
# ...                                       ...                 ...
# GSM4130750_CCACTACAGATGCCAG-6        0.106870               False
# GSM4130750_CCAGCGAAGCTAGCCC-6        0.034335               False
# GSM4130750_CCAGCGAAGTGGAGTC-6        0.041667               False
# GSM4130750_CCAGCGACAAGAGTCG-6        0.285714               False
# GSM4130750_CCAGCGACACATCTTT-6        0.055118               False
#
#                                _scvi_batch  _scvi_labels
# GSM4130750_AAACCTGTCTGCTGCT-1            0             0
# GSM4130750_AAACGGGAGTACGCGA-1            0             0
# GSM4130750_AAACGGGCAGGGATTG-1            0             0
# GSM4130750_AAACGGGCATTGCGGC-1            0             0
# GSM4130750_AAACGGGGTGGGTATG-1            0             0
# ...                                    ...           ...
# GSM4130750_CCACTACAGATGCCAG-6            5             0
# GSM4130750_CCAGCGAAGCTAGCCC-6            5             0
# GSM4130750_CCAGCGAAGTGGAGTC-6            5             0
# GSM4130750_CCAGCGACAAGAGTCG-6            5             0
# GSM4130750_CCAGCGACACATCTTT-6            5             0
#
# [10729 rows x 16 columns]

# %%
sc.pp.neighbors(adata, use_rep = 'X_scVI', random_state = 0) # Use latent representation to build neighbors graph
sc.tl.umap(adata, random_state = 0)

# %%
sc.tl.leiden(adata, key_added='leiden', resolution=1)

# %%
sc.pl.umap(adata, color = ['sample_id'], legend_fontsize = 10)
sc.pl.umap(adata, color = ['leiden'], legend_fontsize = 10)
# Out:
# /home/workspace/environment/sc-spatial/lib/python3.12/site-packages/scanpy/plotting/_tools/scatterplots.py:1234: FutureWarning: The default value of 'ignore' for the `na_action` parameter in pandas.Categorical.map is deprecated and will be changed to 'None' in a future version. Please set na_action to the desired value to avoid seeing this warning
#   color_vector = pd.Categorical(values.map(color_map))
# /home/workspace/environment/sc-spatial/lib/python3.12/site-packages/scanpy/plotting/_tools/scatterplots.py:394: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# /home/workspace/environment/sc-spatial/lib/python3.12/site-packages/scanpy/plotting/_tools/scatterplots.py:1234: FutureWarning: The default value of 'ignore' for the `na_action` parameter in pandas.Categorical.map is deprecated and will be changed to 'None' in a future version. Please set na_action to the desired value to avoid seeing this warning
#   color_vector = pd.Categorical(values.map(color_map))
# /home/workspace/environment/sc-spatial/lib/python3.12/site-packages/scanpy/plotting/_tools/scatterplots.py:394: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %% [markdown]
# # DE

# %%
sc.tl.rank_genes_groups(adata, groupby='leiden', method='wilcoxon')
df = sc.get.rank_genes_groups_df(adata, group = None)
df = df.copy()
df = df[(df.pvals_adj < 0.05) & (df.logfoldchanges > .5)].copy()
df.head(5)

sc.pl.rank_genes_groups(adata, groupby = 'leiden', method = 'wilcoxon')
# Out:
# /home/workspace/environment/sc-spatial/lib/python3.12/site-packages/numpy/core/fromnumeric.py:86: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# /home/workspace/environment/sc-spatial/lib/python3.12/site-packages/scanpy/tools/_rank_genes_groups.py:396: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, 'names'] = self.var_names[global_indices]
# /home/workspace/environment/sc-spatial/lib/python3.12/site-packages/scanpy/tools/_rank_genes_groups.py:398: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, 'scores'] = scores[global_indices]
# /home/workspace/environment/sc-spatial/lib/python3.12/site-packages/scanpy/tools/_rank_genes_groups.py:401: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, 'pvals'] = pvals[global_indices]
# /home/workspace/environment/sc-spatial/lib/python3.12/site-packages/scanpy/tools/_rank_genes_groups.py:411: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, 'pvals_adj'] = pvals_adj[global_indices]
# /home/workspace/environment/sc-spatial/lib/python3.12/site-packages/scanpy/tools/_rank_genes_groups.py:422: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/workspace/environment/sc-spatial/lib/python3.12/site-packages/scanpy/tools/_rank_genes_groups.py:396: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, 'names'] = self.var_names[global_indices]
# /home/workspace/environment/sc-spatial/lib/python3.12/site-packages/scanpy/tools/_rank_genes_groups.py:398: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, 'scores'] = scores[global_indices]
# /home/workspace/environment/sc-spatial/lib/python3.12/site-packages/scanpy/tools/_rank_genes_groups.py:401: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, 'pvals'] = pvals[global_indices]
# /home/workspace/environment/sc-spatial/lib/python3.12/site-packages/scanpy/tools/_rank_genes_groups.py:411: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, 'pvals_adj'] = pvals_adj[global_indices]
# /home/workspace/environment/sc-spatial/lib/python3.12/site-packages/scanpy/tools/_rank_genes_groups.py:422: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/workspace/environment/sc-spatial/lib/python3.12/site-packages/scanpy/tools/_rank_genes_groups.py:396: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, 'names'] = self.var_names[global_indices]
# /home/workspace/environment/sc-spatial/lib/python3.12/site-packages/scanpy/tools/_rank_genes_groups.py:398: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, 'scores'] = scores[global_indices]
# /home/workspace/environment/sc-spatial/lib/python3.12/site-packages/scanpy/tools/_rank_genes_groups.py:401: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, 'pvals'] = pvals[global_indices]
# /home/workspace/environment/sc-spatial/lib/python3.12/site-packages/scanpy/tools/_rank_genes_groups.py:411: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, 'pvals_adj'] = pvals_adj[global_indices]
# /home/workspace/environment/sc-spatial/lib/python3.12/site-packages/scanpy/tools/_rank_genes_groups.py:422: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/workspace/environment/sc-spatial/lib/python3.12/site-packages/scanpy/tools/_rank_genes_groups.py:396: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, 'names'] = self.var_names[global_indices]
# /home/workspace/environment/sc-spatial/lib/python3.12/site-packages/scanpy/tools/_rank_genes_groups.py:398: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, 'scores'] = scores[global_indices]
# /home/workspace/environment/sc-spatial/lib/python3.12/site-packages/scanpy/tools/_rank_genes_groups.py:401: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, 'pvals'] = pvals[global_indices]
# /home/workspace/environment/sc-spatial/lib/python3.12/site-packages/scanpy/tools/_rank_genes_groups.py:411: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, 'pvals_adj'] = pvals_adj[global_indices]
# /home/workspace/environment/sc-spatial/lib/python3.12/site-packages/scanpy/tools/_rank_genes_groups.py:422: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/workspace/environment/sc-spatial/lib/python3.12/site-packages/scanpy/tools/_rank_genes_groups.py:396: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, 'names'] = self.var_names[global_indices]
# /home/workspace/environment/sc-spatial/lib/python3.12/site-packages/scanpy/tools/_rank_genes_groups.py:398: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, 'scores'] = scores[global_indices]
# /home/workspace/environment/sc-spatial/lib/python3.12/site-packages/scanpy/tools/_rank_genes_groups.py:401: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, 'pvals'] = pvals[global_indices]
# /home/workspace/environment/sc-spatial/lib/python3.12/site-packages/scanpy/tools/_rank_genes_groups.py:411: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, 'pvals_adj'] = pvals_adj[global_indices]
# /home/workspace/environment/sc-spatial/lib/python3.12/site-packages/scanpy/tools/_rank_genes_groups.py:422: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/workspace/environment/sc-spatial/lib/python3.12/site-packages/scanpy/tools/_rank_genes_groups.py:396: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, 'names'] = self.var_names[global_indices]
# /home/workspace/environment/sc-spatial/lib/python3.12/site-packages/scanpy/tools/_rank_genes_groups.py:398: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, 'scores'] = scores[global_indices]
# /home/workspace/environment/sc-spatial/lib/python3.12/site-packages/scanpy/tools/_rank_genes_groups.py:401: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, 'pvals'] = pvals[global_indices]
# /home/workspace/environment/sc-spatial/lib/python3.12/site-packages/scanpy/tools/_rank_genes_groups.py:411: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, 'pvals_adj'] = pvals_adj[global_indices]
# /home/workspace/environment/sc-spatial/lib/python3.12/site-packages/scanpy/tools/_rank_genes_groups.py:422: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/workspace/environment/sc-spatial/lib/python3.12/site-packages/scanpy/tools/_rank_genes_groups.py:396: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, 'names'] = self.var_names[global_indices]
# /home/workspace/environment/sc-spatial/lib/python3.12/site-packages/scanpy/tools/_rank_genes_groups.py:398: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, 'scores'] = scores[global_indices]
# /home/workspace/environment/sc-spatial/lib/python3.12/site-packages/scanpy/tools/_rank_genes_groups.py:401: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, 'pvals'] = pvals[global_indices]
# /home/workspace/environment/sc-spatial/lib/python3.12/site-packages/scanpy/tools/_rank_genes_groups.py:411: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, 'pvals_adj'] = pvals_adj[global_indices]
# /home/workspace/environment/sc-spatial/lib/python3.12/site-packages/scanpy/tools/_rank_genes_groups.py:422: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/workspace/environment/sc-spatial/lib/python3.12/site-packages/scanpy/tools/_rank_genes_groups.py:396: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, 'names'] = self.var_names[global_indices]
# /home/workspace/environment/sc-spatial/lib/python3.12/site-packages/scanpy/tools/_rank_genes_groups.py:398: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, 'scores'] = scores[global_indices]
# /home/workspace/environment/sc-spatial/lib/python3.12/site-packages/scanpy/tools/_rank_genes_groups.py:401: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, 'pvals'] = pvals[global_indices]
# /home/workspace/environment/sc-spatial/lib/python3.12/site-packages/scanpy/tools/_rank_genes_groups.py:411: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, 'pvals_adj'] = pvals_adj[global_indices]
# /home/workspace/environment/sc-spatial/lib/python3.12/site-packages/scanpy/tools/_rank_genes_groups.py:422: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/workspace/environment/sc-spatial/lib/python3.12/site-packages/scanpy/tools/_rank_genes_groups.py:396: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, 'names'] = self.var_names[global_indices]
# /home/workspace/environment/sc-spatial/lib/python3.12/site-packages/scanpy/tools/_rank_genes_groups.py:398: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, 'scores'] = scores[global_indices]
# /home/workspace/environment/sc-spatial/lib/python3.12/site-packages/scanpy/tools/_rank_genes_groups.py:401: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, 'pvals'] = pvals[global_indices]
# /home/workspace/environment/sc-spatial/lib/python3.12/site-packages/scanpy/tools/_rank_genes_groups.py:411: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, 'pvals_adj'] = pvals_adj[global_indices]
# /home/workspace/environment/sc-spatial/lib/python3.12/site-packages/scanpy/tools/_rank_genes_groups.py:422: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/workspace/environment/sc-spatial/lib/python3.12/site-packages/scanpy/get/get.py:69: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   d = d.stack(level=1).reset_index()

# %%
sc.pl.umap(adata, color = ['total_counts', 'n_genes_by_counts', 'sample_id', 'pct_counts_mt', 'pct_counts_ribosomal'], legend_fontsize = 10)
# Out:
# /home/workspace/environment/sc-spatial/lib/python3.12/site-packages/scanpy/plotting/_tools/scatterplots.py:1234: FutureWarning: The default value of 'ignore' for the `na_action` parameter in pandas.Categorical.map is deprecated and will be changed to 'None' in a future version. Please set na_action to the desired value to avoid seeing this warning
#   color_vector = pd.Categorical(values.map(color_map))
# /home/workspace/environment/sc-spatial/lib/python3.12/site-packages/scanpy/plotting/_tools/scatterplots.py:394: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
adata.obs
# Out:
#                                       original_annotation        GSE  \
# GSM4130750_AAACCTGTCTGCTGCT-1                  CGRP-Theta  GSE139088
# GSM4130750_AAACGGGAGTACGCGA-1                  CGRP-Gamma  GSE139088
# GSM4130750_AAACGGGCAGGGATTG-1                  CGRP-Alpha  GSE139088
# GSM4130750_AAACGGGCATTGCGGC-1                  CGRP-Alpha  GSE139088
# GSM4130750_AAACGGGGTGGGTATG-1  Nonpeptidergic nociceptors  GSE139088
# ...                                                   ...        ...
# GSM4130750_CCACTACAGATGCCAG-6                 Abeta-Field  GSE139088
# GSM4130750_CCAGCGAAGCTAGCCC-6                  CGRP-Alpha  GSE139088
# GSM4130750_CCAGCGAAGTGGAGTC-6  Nonpeptidergic nociceptors  GSE139088
# GSM4130750_CCAGCGACAAGAGTCG-6                      C-LTMR  GSE139088
# GSM4130750_CCAGCGACACATCTTT-6                  CGRP-Alpha  GSE139088
#
#                                       GSM  sample_number    sample_id  \
# GSM4130750_AAACCTGTCTGCTGCT-1  GSM4130750              1  GSE139088_1
# GSM4130750_AAACGGGAGTACGCGA-1  GSM4130750              1  GSE139088_1
# GSM4130750_AAACGGGCAGGGATTG-1  GSM4130750              1  GSE139088_1
# GSM4130750_AAACGGGCATTGCGGC-1  GSM4130750              1  GSE139088_1
# GSM4130750_AAACGGGGTGGGTATG-1  GSM4130750              1  GSE139088_1
# ...                                   ...            ...          ...
# GSM4130750_CCACTACAGATGCCAG-6  GSM4130750              6  GSE139088_6
# GSM4130750_CCAGCGAAGCTAGCCC-6  GSM4130750              6  GSE139088_6
# GSM4130750_CCAGCGAAGTGGAGTC-6  GSM4130750              6  GSE139088_6
# GSM4130750_CCAGCGACAAGAGTCG-6  GSM4130750              6  GSE139088_6
# GSM4130750_CCAGCGACACATCTTT-6  GSM4130750              6  GSE139088_6
#
#                               experiment_id  n_genes_by_counts  total_counts  \
# GSM4130750_AAACCTGTCTGCTGCT-1     GSE139088               2523        6931.0
# GSM4130750_AAACGGGAGTACGCGA-1     GSE139088               5212       19993.0
# GSM4130750_AAACGGGCAGGGATTG-1     GSE139088               4349       13737.0
# GSM4130750_AAACGGGCATTGCGGC-1     GSE139088               4747       18238.0
# GSM4130750_AAACGGGGTGGGTATG-1     GSE139088               4670       20604.0
# ...                                     ...                ...           ...
# GSM4130750_CCACTACAGATGCCAG-6     GSE139088               3008        7677.0
# GSM4130750_CCAGCGAAGCTAGCCC-6     GSE139088               3811       10125.0
# GSM4130750_CCAGCGAAGTGGAGTC-6     GSE139088               4833       21559.0
# GSM4130750_CCAGCGACAAGAGTCG-6     GSE139088               4843       17804.0
# GSM4130750_CCAGCGACACATCTTT-6     GSE139088               3466        9487.0
#
#                                total_counts_mt  pct_counts_mt  \
# GSM4130750_AAACCTGTCTGCTGCT-1            134.0       1.933343
# GSM4130750_AAACGGGAGTACGCGA-1            430.0       2.150753
# GSM4130750_AAACGGGCAGGGATTG-1            576.0       4.193055
# GSM4130750_AAACGGGCATTGCGGC-1            490.0       2.686698
# GSM4130750_AAACGGGGTGGGTATG-1            514.0       2.494661
# ...                                        ...            ...
# GSM4130750_CCACTACAGATGCCAG-6            168.0       2.188355
# GSM4130750_CCAGCGAAGCTAGCCC-6            412.0       4.069136
# GSM4130750_CCAGCGAAGTGGAGTC-6            692.0       3.209796
# GSM4130750_CCAGCGACAAGAGTCG-6            835.0       4.689957
# GSM4130750_CCAGCGACACATCTTT-6            278.0       2.930326
#
#                                total_counts_ribosomal  pct_counts_ribosomal  \
# GSM4130750_AAACCTGTCTGCTGCT-1                   326.0              4.703506
# GSM4130750_AAACGGGAGTACGCGA-1                  1430.0              7.152503
# GSM4130750_AAACGGGCAGGGATTG-1                  1143.0              8.320594
# GSM4130750_AAACGGGCATTGCGGC-1                  1593.0              8.734510
# GSM4130750_AAACGGGGTGGGTATG-1                  1450.0              7.037468
# ...                                               ...                   ...
# GSM4130750_CCACTACAGATGCCAG-6                   381.0              4.962876
# GSM4130750_CCAGCGAAGCTAGCCC-6                   948.0              9.362963
# GSM4130750_CCAGCGAAGTGGAGTC-6                  2056.0              9.536620
# GSM4130750_CCAGCGACAAGAGTCG-6                  1185.0              6.655808
# GSM4130750_CCAGCGACACATCTTT-6                   914.0              9.634236
#
#                                doublet_scores  predicted_doublets  \
# GSM4130750_AAACCTGTCTGCTGCT-1        0.070248               False
# GSM4130750_AAACGGGAGTACGCGA-1        0.044776               False
# GSM4130750_AAACGGGCAGGGATTG-1        0.025710               False
# GSM4130750_AAACGGGCATTGCGGC-1        0.036697               False
# GSM4130750_AAACGGGGTGGGTATG-1        0.036697               False
# ...                                       ...                 ...
# GSM4130750_CCACTACAGATGCCAG-6        0.106870               False
# GSM4130750_CCAGCGAAGCTAGCCC-6        0.034335               False
# GSM4130750_CCAGCGAAGTGGAGTC-6        0.041667               False
# GSM4130750_CCAGCGACAAGAGTCG-6        0.285714               False
# GSM4130750_CCAGCGACACATCTTT-6        0.055118               False
#
#                                _scvi_batch  _scvi_labels leiden
# GSM4130750_AAACCTGTCTGCTGCT-1            0             0      5
# GSM4130750_AAACGGGAGTACGCGA-1            0             0      9
# GSM4130750_AAACGGGCAGGGATTG-1            0             0      0
# GSM4130750_AAACGGGCATTGCGGC-1            0             0      0
# GSM4130750_AAACGGGGTGGGTATG-1            0             0      4
# ...                                    ...           ...    ...
# GSM4130750_CCACTACAGATGCCAG-6            5             0      8
# GSM4130750_CCAGCGAAGCTAGCCC-6            5             0      0
# GSM4130750_CCAGCGAAGTGGAGTC-6            5             0      1
# GSM4130750_CCAGCGACAAGAGTCG-6            5             0      6
# GSM4130750_CCAGCGACACATCTTT-6            5             0      0
#
# [10729 rows x 17 columns]

# %%
sc.pl.umap(adata, color = ['Rbfox3', 'Th', 'Piezo1', 'Piezo2', 'Aif1', 'P2ry12', 'Itgam', 'Trpv1', 'original_annotation', 'pct_counts_mt', 'pct_counts_ribosomal', 'doublet_scores'], legend_fontsize = 10)
# Out:
# /home/workspace/environment/sc-spatial/lib/python3.12/site-packages/scanpy/plotting/_tools/scatterplots.py:1234: FutureWarning: The default value of 'ignore' for the `na_action` parameter in pandas.Categorical.map is deprecated and will be changed to 'None' in a future version. Please set na_action to the desired value to avoid seeing this warning
#   color_vector = pd.Categorical(values.map(color_map))
# /home/workspace/environment/sc-spatial/lib/python3.12/site-packages/scanpy/plotting/_tools/scatterplots.py:394: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
sc.pl.umap(adata, color = ['original_annotation'], title = "Author Annotations", frameon = False, size = 4)
# Out:
# /home/workspace/environment/sc-spatial/lib/python3.12/site-packages/scanpy/plotting/_tools/scatterplots.py:1234: FutureWarning: The default value of 'ignore' for the `na_action` parameter in pandas.Categorical.map is deprecated and will be changed to 'None' in a future version. Please set na_action to the desired value to avoid seeing this warning
#   color_vector = pd.Categorical(values.map(color_map))
# /home/workspace/environment/sc-spatial/lib/python3.12/site-packages/scanpy/plotting/_tools/scatterplots.py:394: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
sc.pl.umap(adata, color = ['leiden'], title = "Cluster", frameon = False, size = 4)
# Out:
# /home/workspace/environment/sc-spatial/lib/python3.12/site-packages/scanpy/plotting/_tools/scatterplots.py:1234: FutureWarning: The default value of 'ignore' for the `na_action` parameter in pandas.Categorical.map is deprecated and will be changed to 'None' in a future version. Please set na_action to the desired value to avoid seeing this warning
#   color_vector = pd.Categorical(values.map(color_map))
# /home/workspace/environment/sc-spatial/lib/python3.12/site-packages/scanpy/plotting/_tools/scatterplots.py:394: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
sc.pl.umap(adata, color = ['Rbfox3', 'Mbp', 'Th'], frameon = False, size = 4)

# %%
sc.pl.umap(adata, color = ['Trpv1'], frameon = False, size = 4)

# %%
# Number of cells
n_cells = adata.n_obs

# Median total counts per cell (transcript count)
median_total_counts = adata.obs['total_counts'].median()

# Median number of genes detected per cell
median_n_genes = adata.obs['n_genes_by_counts'].median()

# Print results
print(f"Number of cells: {n_cells:,}")
print(f"Median total counts per cell: {median_total_counts:.0f}")
print(f"Median number of detected genes per cell: {median_n_genes:.0f}")
# Out:
# Number of cells: 10,729
# Median total counts per cell: 15117
# Median number of detected genes per cell: 4311

# %% [markdown]
# ## Export

# %%
adata.write_h5ad(h5ad_out, compression='gzip')
